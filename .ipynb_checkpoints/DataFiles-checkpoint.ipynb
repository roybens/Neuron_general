# %% [markdown]
# # Opening Files
# For this excercise you will be learning how to open and read in a file. To have files to work with on the system you must first upload them into the system.
# 1. Go to [http://tiny.cc/6x5mzz](http://tiny.cc/6x5mzz) to download the file to your local machine.
# 1. On the left side there is a folder icon that when clicked on will show Files in the session storage. There is an icon that looks like a file with a up arrow on it. Click on it and select the `state_codes.json` file you downloaded from [http://tiny.cc/6x5mzz](http://tiny.cc/6x5mzz).
# 1. Repeat the previousl steps for [http://tiny.cc/8x5mzz](http://tiny.cc/8x5mzz) (`area-codes-usa.csv`), and [http://tiny.cc/fx5mzz](http://tiny.cc/fx5mzz) (`uszips.csv`).
#
# Once you've uploaded the files into the system you are ready to try and open your first file. You can open and read the contents of a text file using the format:
# ```python
# with open(filename_goes_here,'r') as file_variable_name:
#   data_storage_variable = file_variable_name.read()
# ```
# The `filename_goes_here` can be a variable or literal string with the name of the file to be opened. The `'r'` parameter in the open statement says that the file is to be opened for reading. The `with` statement at the beginning says to treat the result the expression before the `as` as the variable name after it (in this case the `file_variable_name`). In practice it is good to open files using the `with` block so that the file is automatically closed when the block of code within the `with` is completed. The `.read()` method reads in the contents of the file and since we are assigning it to a variable will place it in that variable (in this case the `data_storage_variable`). The `filename_goes_here`, `file_variable_name`, and `data_storage_variable` variable names could be any valid variable name.
#
# 1. Create a variable called `state_code_filename` to hold the filename of the `state_codes.json`.
# 1. Open the `state_codes.json` file and read the contents into a variable named `state_code_raw_data`.
# 1. You should be able to print out the contents of the file using print the first few lines of file using the line:
# ```python
# print('\n'.join(state_code_raw_data.split('\n')[:5]))
# ```
# and should see something like:
# ```
# [
#   {
#     "state": "Alabama",
#     "abbrev": "Ala.",
#     "code": "AL"
# ```
# 1. Verify your code works with the test block afterward.
#
# Data Sources: The data for `state_codes.json` is from [here](https://worldpopulationreview.com/states/state-abbreviations), the data for `area-codes-usa.csv` is from [here](https://dedolist.com/lists/business/area-codes-usa/csv/), and the data for `uszips.csv` is from [here](https://simplemaps.com/data/us-zips).

# %%
# Replace ... with your code
state_code_filename = 'state_codes.json'
with open(state_code_filename,'r') as m:
    state_code_raw_data = m.read()
    
print('\n'.join(state_code_raw_data.split('\n')[:5]))
# Out:
# [
#   {
#     "state": "Alabama",
#     "abbrev": "Ala.",
#     "code": "AL"

# %% [markdown]
# Run the code block below after running your code to check that it is correct. If you see an output of `Correct` below the block everything is correct. If you see something like `AssertionError`, then you have a mistake.

# %%
# Don't modify this code
import hashlib
assert 'state_code_filename' in locals()
assert type(state_code_filename) == str
assert state_code_filename == 'state_codes.json'
assert 'state_code_raw_data' in locals()
assert type(state_code_raw_data) == str
assert len(state_code_raw_data) == 3773
assert hashlib.md5(state_code_raw_data.encode('utf-8')).hexdigest() == 'aa6718b8b969137de605a87f67b15331'
print('Correct')
# Out:
# Correct

# %% [markdown]
# # Loading JSON Files
# For this excercise you will be opening a JSON file and loading it into a python variable as actual data objects and not just plain text. You will also be creating two translation dictionaries for translating between state names and codes. There are multiple ways to load JSON files, but we will be using the [`json.load()`](https://docs.python.org/3/library/json.html#json.load) method. The [`json.load()`](https://docs.python.org/3/library/json.html#json.load) method takes in a file as a parameter, so instead of the line previous line to read in of:
# ```python
#   data_storage_variable = file_variable_name.read()
# ```
# You will instead use:
# ```python
#   data_storage_variable = json.load(file_variable_name)
# ```
# The `data_storage_variable` will be an object with the JSON file contents instead of just a string of the characters in the file. You will also need to iterate over all values in a list using a `for` loop. The syntax of the `for` loop is:
# ```python
# for item in some_list:
#   ... # do something with item here
# ```
# For each iteration of the loop `item` will take the value of the items in `some_list`. Now load the JSON file and create a translation dictionary between state names and codes.
#
# 1. Make sure that your previous excercise works, and that it has been run, otherwise create the `state_code_filename` variable.
# 1. Open the `state_codes.json` file and read JSON data into a variable named `state_code_data`.
# 1. If you print the variable you should see something like:
# ```
# [{'state': 'Alabama', 'abbrev': 'Ala.', 'code': 'AL'}, {'state': 'Alaska', 'abbrev': 'Alaska', 'code': 'AK'}, ...
# ```
# 1. Create a empty dictionary variable called `state_name_to_code`, an empty dictionary is just `dict()`.
# 1. Iterate through all of the states in the `state_code_data` with a for loop, and insert the state code values mapped to their state name keys into the `state_name_to_code` dictionary. The `'state'` key is the name of the state, and the `'code'` key is the code for each state.
# 1. Repeat the previous two steps for `state_code_to_name` that will translate between codes to names.
# 1. Verify your code works with the test block afterward.

# %%
import json
# Replace ... with your code
state_code_filename = 'state_codes.json'
with open(state_code_filename,'r') as m:
    state_code_data = json.load(m)
    
state_name_to_code = dict()
state_code_to_name = dict()

for state in state_code_data:
    state_name = state['state']
    state_code = state['code']
    state_name_to_code[state_name] = state_code
    state_code_to_name[state_code] = state_name

# %% [markdown]
# Run the code block below after running your code to check that it is correct. If you see an output of `Correct` below the block everything is correct. If you see something like `AssertionError`, then you have a mistake.

# %%
# Don't modify this code
assert 'state_code_data' in locals()
assert type(state_code_data) == list
assert len(state_code_data) == 51
assert 'state_name_to_code' in locals()
assert type(state_name_to_code) == dict
assert len(state_name_to_code) == 51
assert state_name_to_code['California'] == 'CA'
assert 'state_code_to_name' in locals()
assert type(state_code_to_name) == dict
assert len(state_code_to_name) == 51
assert state_code_to_name['CA'] == 'California'
print('Correct')
# Out:
# Correct

# %% [markdown]
# # Loading CSV
# For this exercise you will be loading the area and zip code CSV files. Similar to loading in JSON data, there methods to load in CSV data. There are multiple ways to read in CSV data, but for this exercise you will be using the [`csv.DictReader()`](https://docs.python.org/3/library/csv.html#csv.DictReader) to read in the rows of the CSV file as dictionaries. Like the [`json.load()`](https://docs.python.org/3/library/json.html#json.load) method, the [`csv.DictReader()`](https://docs.python.org/3/library/csv.html#csv.DictReader) takes in a file as a parameter; however, it creates a sequence that you will want to convert to a list. So instead of the line previous line to read in of:
# ```python
#   data_storage_variable = file_variable_name.read()
# ```
# You will instead use:
# ```python
#   data_storage_variable = list(csv.DictReader(file_variable_name))
# ```
#
# 1. Create a variable called `area_code_filename` to hold the filename of the `area-codes-usa.csv`.
# 1. Open the `area-codes-usa.csv` file and read the contents into a variable named `area_code_data`.
# 1. If you print the first item of the `area_code_data` you should see something like:
# ```
# {'area-code': '201', 'city': 'Bayonne', 'state': 'New Jersey', 'country': 'US', 'latitude': '40.66871', 'longitude': '-74.11431'}
# ```
# 1. Create a variable called `zip_code_filename` to hold the filename of the `uszips.csv`.
# 1. Open the `uszips.csv` file and read the contents into a variable named `zip_code_data`.
# 1. If you print the first item of the `zip_code_data` you should see something like:
# ```
# {'zip': '00601', 'lat': '18.18027', 'lng': '-66.75266', 'city': 'Adjuntas', 'state_id': 'PR', 'state_name': 'Puerto Rico', ...
# ```
# 1. Verify your code works with the test block afterward.

# %%
import csv
# Replace ... with your code
area_code_filename = 'area-codes-usa.csv'
zip_code_filename = 'uszips.csv'

with open(area_code_filename, 'r') as a:
    area_code_data = list(csv.DictReader(a))
with open(zip_code_filename, 'r') as z:
    zip_code_data = list(csv.DictReader(z))
    
zip_code_data
# Out:
# [{'zip': '00601',
#   'lat': '18.18027',
#   'lng': '-66.75266',
#   'city': 'Adjuntas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '16773',
#   'density': '100.5',
#   'county_fips': '72001',
#   'county_name': 'Adjuntas',
#   'county_weights': '{"72001": 98.73, "72141": 1.27}',
#   'county_names_all': 'Adjuntas|Utuado',
#   'county_fips_all': '72001|72141',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00602',
#   'lat': '18.36075',
#   'lng': '-67.17541',
#   'city': 'Aguada',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '37083',
#   'density': '472.1',
#   'county_fips': '72003',
#   'county_name': 'Aguada',
#   'county_weights': '{"72003": 100}',
#   'county_names_all': 'Aguada',
#   'county_fips_all': '72003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00603',
#   'lat': '18.45744',
#   'lng': '-67.12225',
#   'city': 'Aguadilla',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '45652',
#   'density': '513.2',
#   'county_fips': '72005',
#   'county_name': 'Aguadilla',
#   'county_weights': '{"72005": 99.76, "72099": 0.24}',
#   'county_names_all': 'Aguadilla|Moca',
#   'county_fips_all': '72005|72099',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00606',
#   'lat': '18.16585',
#   'lng': '-66.93716',
#   'city': 'Maricao',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '6231',
#   'density': '54.3',
#   'county_fips': '72093',
#   'county_name': 'Maricao',
#   'county_weights': '{"72093": 82.26, "72153": 11.68, "72121": 6.06}',
#   'county_names_all': 'Maricao|Yauco|Sabana Grande',
#   'county_fips_all': '72093|72153|72121',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00610',
#   'lat': '18.2911',
#   'lng': '-67.12243',
#   'city': 'Anasco',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '26502',
#   'density': '275.7',
#   'county_fips': '72011',
#   'county_name': 'Añasco',
#   'county_weights': '{"72011": 96.71, "72099": 2.81, "72083": 0.37, "72003": 0.11}',
#   'county_names_all': 'Añasco|Moca|Las Marías|Aguada',
#   'county_fips_all': '72011|72099|72083|72003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00611',
#   'lat': '18.27698',
#   'lng': '-66.80688',
#   'city': 'Angeles',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '72141',
#   'county_name': 'Utuado',
#   'county_weights': '{"72141": 100}',
#   'county_names_all': 'Utuado',
#   'county_fips_all': '72141',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00612',
#   'lat': '18.41283',
#   'lng': '-66.7051',
#   'city': 'Arecibo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '58771',
#   'density': '298.0',
#   'county_fips': '72013',
#   'county_name': 'Arecibo',
#   'county_weights': '{"72013": 98.86, "72065": 0.94, "72017": 0.2}',
#   'county_names_all': 'Arecibo|Hatillo|Barceloneta',
#   'county_fips_all': '72013|72065|72017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00616',
#   'lat': '18.41878',
#   'lng': '-66.6679',
#   'city': 'Bajadero',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '9688',
#   'density': '343.7',
#   'county_fips': '72013',
#   'county_name': 'Arecibo',
#   'county_weights': '{"72013": 100}',
#   'county_names_all': 'Arecibo',
#   'county_fips_all': '72013',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00617',
#   'lat': '18.44598',
#   'lng': '-66.56006',
#   'city': 'Barceloneta',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '23771',
#   'density': '500.0',
#   'county_fips': '72017',
#   'county_name': 'Barceloneta',
#   'county_weights': '{"72017": 99.63, "72054": 0.37}',
#   'county_names_all': 'Barceloneta|Florida',
#   'county_fips_all': '72017|72054',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00622',
#   'lat': '17.98892',
#   'lng': '-67.1566',
#   'city': 'Boqueron',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '6505',
#   'density': '80.6',
#   'county_fips': '72023',
#   'county_name': 'Cabo Rojo',
#   'county_weights': '{"72023": 100}',
#   'county_names_all': 'Cabo Rojo',
#   'county_fips_all': '72023',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00623',
#   'lat': '18.08429',
#   'lng': '-67.15336',
#   'city': 'Cabo Rojo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '41472',
#   'density': '408.5',
#   'county_fips': '72023',
#   'county_name': 'Cabo Rojo',
#   'county_weights': '{"72023": 100}',
#   'county_names_all': 'Cabo Rojo',
#   'county_fips_all': '72023',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00624',
#   'lat': '18.05905',
#   'lng': '-66.71932',
#   'city': 'Penuelas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '21031',
#   'density': '172.9',
#   'county_fips': '72111',
#   'county_name': 'Peñuelas',
#   'county_weights': '{"72111": 94.96, "72113": 5.04}',
#   'county_names_all': 'Peñuelas|Ponce',
#   'county_fips_all': '72111|72113',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00627',
#   'lat': '18.41905',
#   'lng': '-66.86037',
#   'city': 'Camuy',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '31066',
#   'density': '258.7',
#   'county_fips': '72027',
#   'county_name': 'Camuy',
#   'county_weights': '{"72027": 100}',
#   'county_names_all': 'Camuy',
#   'county_fips_all': '72027',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00631',
#   'lat': '18.1852',
#   'lng': '-66.83169',
#   'city': 'Castaner',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1481',
#   'density': '182.9',
#   'county_fips': '72081',
#   'county_name': 'Lares',
#   'county_weights': '{"72081": 50.58, "72001": 49.42}',
#   'county_names_all': 'Lares|Adjuntas',
#   'county_fips_all': '72081|72001',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00636',
#   'lat': '18.16354',
#   'lng': '-67.08014',
#   'city': 'Rosario',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '72125',
#   'county_name': 'San Germán',
#   'county_weights': '{"72125": 100}',
#   'county_names_all': 'San Germán',
#   'county_fips_all': '72125',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00637',
#   'lat': '18.081',
#   'lng': '-66.94659',
#   'city': 'Sabana Grande',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '21957',
#   'density': '241.0',
#   'county_fips': '72121',
#   'county_name': 'Sabana Grande',
#   'county_weights': '{"72121": 94.01, "72125": 4.2, "72079": 1.79}',
#   'county_names_all': 'Sabana Grande|San Germán|Lajas',
#   'county_fips_all': '72121|72125|72079',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00638',
#   'lat': '18.28462',
#   'lng': '-66.5137',
#   'city': 'Ciales',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '16018',
#   'density': '86.6',
#   'county_fips': '72039',
#   'county_name': 'Ciales',
#   'county_weights': '{"72039": 91.88, "72107": 7.48, "72091": 0.64}',
#   'county_names_all': 'Ciales|Orocovis|Manatí',
#   'county_fips_all': '72039|72107|72091',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00641',
#   'lat': '18.26742',
#   'lng': '-66.70212',
#   'city': 'Utuado',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '26383',
#   'density': '121.1',
#   'county_fips': '72141',
#   'county_name': 'Utuado',
#   'county_weights': '{"72141": 100}',
#   'county_names_all': 'Utuado',
#   'county_fips_all': '72141',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00646',
#   'lat': '18.43251',
#   'lng': '-66.28429',
#   'city': 'Dorado',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '36538',
#   'density': '670.1',
#   'county_fips': '72051',
#   'county_name': 'Dorado',
#   'county_weights': '{"72051": 97.19, "72143": 2.81}',
#   'county_names_all': 'Dorado|Vega Alta',
#   'county_fips_all': '72051|72143',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00647',
#   'lat': '17.96667',
#   'lng': '-66.94266',
#   'city': 'Ensenada',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '5708',
#   'density': '139.4',
#   'county_fips': '72055',
#   'county_name': 'Guánica',
#   'county_weights': '{"72055": 98.36, "72079": 1.64}',
#   'county_names_all': 'Guánica|Lajas',
#   'county_fips_all': '72055|72079',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00650',
#   'lat': '18.34487',
#   'lng': '-66.58347',
#   'city': 'Florida',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '13869',
#   'density': '168.8',
#   'county_fips': '72054',
#   'county_name': 'Florida',
#   'county_weights': '{"72054": 47.43, "72141": 41.94, "72091": 4.26, "72039": 2.9, "72013": 2.41, "72017": 1.07}',
#   'county_names_all': 'Florida|Utuado|Manatí|Ciales|Arecibo|Barceloneta',
#   'county_fips_all': '72054|72141|72091|72039|72013|72017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00652',
#   'lat': '18.45614',
#   'lng': '-66.60194',
#   'city': 'Garrochales',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '3624',
#   'density': '217.2',
#   'county_fips': '72013',
#   'county_name': 'Arecibo',
#   'county_weights': '{"72013": 100}',
#   'county_names_all': 'Arecibo',
#   'county_fips_all': '72013',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00653',
#   'lat': '17.99413',
#   'lng': '-66.90266',
#   'city': 'Guanica',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '10117',
#   'density': '176.9',
#   'county_fips': '72055',
#   'county_name': 'Guánica',
#   'county_weights': '{"72055": 97.54, "72121": 2.46}',
#   'county_names_all': 'Guánica|Sabana Grande',
#   'county_fips_all': '72055|72121',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00656',
#   'lat': '18.04186',
#   'lng': '-66.79123',
#   'city': 'Guayanilla',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '17984',
#   'density': '164.8',
#   'county_fips': '72059',
#   'county_name': 'Guayanilla',
#   'county_weights': '{"72059": 96.96, "72153": 2.88, "72111": 0.16}',
#   'county_names_all': 'Guayanilla|Yauco|Peñuelas',
#   'county_fips_all': '72059|72153|72111',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00659',
#   'lat': '18.41036',
#   'lng': '-66.79691',
#   'city': 'Hatillo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '39561',
#   'density': '372.0',
#   'county_fips': '72065',
#   'county_name': 'Hatillo',
#   'county_weights': '{"72065": 100}',
#   'county_names_all': 'Hatillo',
#   'county_fips_all': '72065',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00660',
#   'lat': '18.13412',
#   'lng': '-67.11399',
#   'city': 'Hormigueros',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '15731',
#   'density': '536.6',
#   'county_fips': '72067',
#   'county_name': 'Hormigueros',
#   'county_weights': '{"72067": 100}',
#   'county_names_all': 'Hormigueros',
#   'county_fips_all': '72067',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00662',
#   'lat': '18.46622',
#   'lng': '-67.01508',
#   'city': 'Isabela',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '39017',
#   'density': '365.0',
#   'county_fips': '72071',
#   'county_name': 'Isabela',
#   'county_weights': '{"72071": 100}',
#   'county_names_all': 'Isabela',
#   'county_fips_all': '72071',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00664',
#   'lat': '18.21064',
#   'lng': '-66.59066',
#   'city': 'Jayuya',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '14405',
#   'density': '118.6',
#   'county_fips': '72073',
#   'county_name': 'Jayuya',
#   'county_weights': '{"72073": 94.97, "72141": 5.03}',
#   'county_names_all': 'Jayuya|Utuado',
#   'county_fips_all': '72073|72141',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00667',
#   'lat': '18.01246',
#   'lng': '-67.0417',
#   'city': 'Lajas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '22721',
#   'density': '145.7',
#   'county_fips': '72079',
#   'county_name': 'Lajas',
#   'county_weights': '{"72079": 98.09, "72125": 1.91}',
#   'county_names_all': 'Lajas|San Germán',
#   'county_fips_all': '72079|72125',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00669',
#   'lat': '18.27019',
#   'lng': '-66.86727',
#   'city': 'Lares',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '24022',
#   'density': '144.7',
#   'county_fips': '72081',
#   'county_name': 'Lares',
#   'county_weights': '{"72081": 93.38, "72141": 3.8, "72083": 2.7, "72131": 0.12}',
#   'county_names_all': 'Lares|Utuado|Las Marías|San Sebastián',
#   'county_fips_all': '72081|72141|72083|72131',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00670',
#   'lat': '18.23782',
#   'lng': '-66.98852',
#   'city': 'Las Marias',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '8051',
#   'density': '66.8',
#   'county_fips': '72083',
#   'county_name': 'Las Marías',
#   'county_weights': '{"72083": 95.63, "72011": 3.6, "72097": 0.45, "72093": 0.32}',
#   'county_names_all': 'Las Marías|Añasco|Mayagüez|Maricao',
#   'county_fips_all': '72083|72011|72097|72093',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00674',
#   'lat': '18.42229',
#   'lng': '-66.4891',
#   'city': 'Manati',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '38218',
#   'density': '339.6',
#   'county_fips': '72091',
#   'county_name': 'Manatí',
#   'county_weights': '{"72091": 99.45, "72145": 0.55}',
#   'county_names_all': 'Manatí|Vega Baja',
#   'county_fips_all': '72091|72145',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00676',
#   'lat': '18.37897',
#   'lng': '-67.08098',
#   'city': 'Moca',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '35621',
#   'density': '281.5',
#   'county_fips': '72099',
#   'county_name': 'Moca',
#   'county_weights': '{"72099": 99.19, "72003": 0.81}',
#   'county_names_all': 'Moca|Aguada',
#   'county_fips_all': '72099|72003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00677',
#   'lat': '18.33535',
#   'lng': '-67.23155',
#   'city': 'Rincon',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '13949',
#   'density': '369.7',
#   'county_fips': '72117',
#   'county_name': 'Rincón',
#   'county_weights': '{"72117": 98.0, "72011": 1.19, "72003": 0.81}',
#   'county_names_all': 'Rincón|Añasco|Aguada',
#   'county_fips_all': '72117|72011|72003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00678',
#   'lat': '18.42949',
#   'lng': '-66.93016',
#   'city': 'Quebradillas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '24997',
#   'density': '331.2',
#   'county_fips': '72115',
#   'county_name': 'Quebradillas',
#   'county_weights': '{"72115": 77.11, "72071": 17.13, "72131": 5.76}',
#   'county_names_all': 'Quebradillas|Isabela|San Sebastián',
#   'county_fips_all': '72115|72071|72131',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00680',
#   'lat': '18.16307',
#   'lng': '-67.36122',
#   'city': 'Mayaguez',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '44904',
#   'density': '269.6',
#   'county_fips': '72097',
#   'county_name': 'Mayagüez',
#   'county_weights': '{"72097": 94.13, "72125": 3.44, "72011": 2.43}',
#   'county_names_all': 'Mayagüez|San Germán|Añasco',
#   'county_fips_all': '72097|72125|72011',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00682',
#   'lat': '18.22415',
#   'lng': '-67.15309',
#   'city': 'Mayaguez',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '30212',
#   'density': '715.2',
#   'county_fips': '72097',
#   'county_name': 'Mayagüez',
#   'county_weights': '{"72097": 99.83, "72067": 0.17}',
#   'county_names_all': 'Mayagüez|Hormigueros',
#   'county_fips_all': '72097|72067',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00683',
#   'lat': '18.10926',
#   'lng': '-67.03803',
#   'city': 'San German',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '28710',
#   'density': '224.9',
#   'county_fips': '72125',
#   'county_name': 'San Germán',
#   'county_weights': '{"72125": 100}',
#   'county_names_all': 'San Germán',
#   'county_fips_all': '72125',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00685',
#   'lat': '18.33656',
#   'lng': '-66.97518',
#   'city': 'San Sebastian',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '36546',
#   'density': '179.3',
#   'county_fips': '72131',
#   'county_name': 'San Sebastián',
#   'county_weights': '{"72131": 87.74, "72071": 11.31, "72099": 0.95}',
#   'county_names_all': 'San Sebastián|Isabela|Moca',
#   'county_fips_all': '72131|72071|72099',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00687',
#   'lat': '18.31707',
#   'lng': '-66.42029',
#   'city': 'Morovis',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '30652',
#   'density': '304.5',
#   'county_fips': '72101',
#   'county_name': 'Morovis',
#   'county_weights': '{"72101": 100}',
#   'county_names_all': 'Morovis',
#   'county_fips_all': '72101',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00688',
#   'lat': '18.3807',
#   'lng': '-66.62496',
#   'city': 'Sabana Hoyos',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '11355',
#   'density': '134.9',
#   'county_fips': '72013',
#   'county_name': 'Arecibo',
#   'county_weights': '{"72013": 100}',
#   'county_names_all': 'Arecibo',
#   'county_fips_all': '72013',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00690',
#   'lat': '18.49363',
#   'lng': '-67.09734',
#   'city': 'San Antonio',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '5900',
#   'density': '1007.5',
#   'county_fips': '72005',
#   'county_name': 'Aguadilla',
#   'county_weights': '{"72005": 100}',
#   'county_names_all': 'Aguadilla',
#   'county_fips_all': '72005',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00692',
#   'lat': '18.40905',
#   'lng': '-66.33768',
#   'city': 'Vega Alta',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '34857',
#   'density': '507.3',
#   'county_fips': '72143',
#   'county_name': 'Vega Alta',
#   'county_weights': '{"72143": 99.87, "72145": 0.13}',
#   'county_names_all': 'Vega Alta|Vega Baja',
#   'county_fips_all': '72143|72145',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00693',
#   'lat': '18.42633',
#   'lng': '-66.39811',
#   'city': 'Vega Baja',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '52220',
#   'density': '454.0',
#   'county_fips': '72145',
#   'county_name': 'Vega Baja',
#   'county_weights': '{"72145": 98.28, "72143": 1.43, "72091": 0.29}',
#   'county_names_all': 'Vega Baja|Vega Alta|Manatí',
#   'county_fips_all': '72145|72143|72091',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00694',
#   'lat': '18.48327',
#   'lng': '-66.39269',
#   'city': 'Vega Baja',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '32',
#   'density': '15.5',
#   'county_fips': '72145',
#   'county_name': 'Vega Baja',
#   'county_weights': '{"72145": 100}',
#   'county_names_all': 'Vega Baja',
#   'county_fips_all': '72145',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00698',
#   'lat': '18.07274',
#   'lng': '-66.85519',
#   'city': 'Yauco',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '34449',
#   'density': '212.3',
#   'county_fips': '72153',
#   'county_name': 'Yauco',
#   'county_weights': '{"72153": 97.82, "72059": 2.18}',
#   'county_names_all': 'Yauco|Guayanilla',
#   'county_fips_all': '72153|72059',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00703',
#   'lat': '18.24739',
#   'lng': '-66.13143',
#   'city': 'Aguas Buenas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '25619',
#   'density': '318.9',
#   'county_fips': '72007',
#   'county_name': 'Aguas Buenas',
#   'county_weights': '{"72007": 93.07, "72041": 3.61, "72045": 3.32}',
#   'county_names_all': 'Aguas Buenas|Cidra|Comerío',
#   'county_fips_all': '72007|72041|72045',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00704',
#   'lat': '17.97442',
#   'lng': '-66.22888',
#   'city': 'Aguirre',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '7641',
#   'density': '327.9',
#   'county_fips': '72123',
#   'county_name': 'Salinas',
#   'county_weights': '{"72123": 97.64, "72057": 2.36}',
#   'county_names_all': 'Salinas|Guayama',
#   'county_fips_all': '72123|72057',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00705',
#   'lat': '18.1294',
#   'lng': '-66.26653',
#   'city': 'Aibonito',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '22289',
#   'density': '283.0',
#   'county_fips': '72009',
#   'county_name': 'Aibonito',
#   'county_weights': '{"72009": 97.19, "72043": 2.81}',
#   'county_names_all': 'Aibonito|Coamo',
#   'county_fips_all': '72009|72043',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00707',
#   'lat': '18.01752',
#   'lng': '-65.92127',
#   'city': 'Maunabo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '10514',
#   'density': '194.0',
#   'county_fips': '72095',
#   'county_name': 'Maunabo',
#   'county_weights': '{"72095": 100}',
#   'county_names_all': 'Maunabo',
#   'county_fips_all': '72095',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00714',
#   'lat': '17.9981',
#   'lng': '-66.05635',
#   'city': 'Arroyo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '17413',
#   'density': '448.1',
#   'county_fips': '72015',
#   'county_name': 'Arroyo',
#   'county_weights': '{"72015": 100}',
#   'county_names_all': 'Arroyo',
#   'county_fips_all': '72015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00715',
#   'lat': '17.99738',
#   'lng': '-66.56104',
#   'city': 'Mercedita',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '2846',
#   'density': '86.5',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 99.08, "72075": 0.92}',
#   'county_names_all': 'Ponce|Juana Díaz',
#   'county_fips_all': '72113|72075',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00716',
#   'lat': '17.99942',
#   'lng': '-66.59868',
#   'city': 'Ponce',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '26433',
#   'density': '1177.4',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 100}',
#   'county_names_all': 'Ponce',
#   'county_fips_all': '72113',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00717',
#   'lat': '18.00272',
#   'lng': '-66.61146',
#   'city': 'Ponce',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '15115',
#   'density': '2459.5',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 100}',
#   'county_names_all': 'Ponce',
#   'county_fips_all': '72113',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00718',
#   'lat': '18.23145',
#   'lng': '-65.76067',
#   'city': 'Naguabo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '25543',
#   'density': '208.9',
#   'county_fips': '72103',
#   'county_name': 'Naguabo',
#   'county_weights': '{"72103": 99.86, "72037": 0.14}',
#   'county_names_all': 'Naguabo|Ceiba',
#   'county_fips_all': '72103|72037',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00719',
#   'lat': '18.28879',
#   'lng': '-66.25316',
#   'city': 'Naranjito',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '28048',
#   'density': '383.9',
#   'county_fips': '72105',
#   'county_name': 'Naranjito',
#   'county_weights': '{"72105": 96.91, "72047": 2.22, "72045": 0.47, "72135": 0.4}',
#   'county_names_all': 'Naranjito|Corozal|Comerío|Toa Alta',
#   'county_fips_all': '72105|72047|72045|72135',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00720',
#   'lat': '18.21559',
#   'lng': '-66.42421',
#   'city': 'Orocovis',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '20387',
#   'density': '140.2',
#   'county_fips': '72107',
#   'county_name': 'Orocovis',
#   'county_weights': '{"72107": 99.27, "72043": 0.73}',
#   'county_names_all': 'Orocovis|Coamo',
#   'county_fips_all': '72107|72043',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00723',
#   'lat': '18.03139',
#   'lng': '-66.01122',
#   'city': 'Patillas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '16645',
#   'density': '139.7',
#   'county_fips': '72109',
#   'county_name': 'Patillas',
#   'county_weights': '{"72109": 99.5, "72095": 0.5}',
#   'county_names_all': 'Patillas|Maunabo',
#   'county_fips_all': '72109|72095',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00725',
#   'lat': '18.22052',
#   'lng': '-66.03962',
#   'city': 'Caguas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '79395',
#   'density': '741.1',
#   'county_fips': '72025',
#   'county_name': 'Caguas',
#   'county_weights': '{"72025": 86.56, "72061": 4.45, "72129": 2.77, "72127": 2.23, "72139": 2.08, "72007": 1.9}',
#   'county_names_all': 'Caguas|Guaynabo|San Lorenzo|San Juan|Trujillo Alto|Aguas Buenas',
#   'county_fips_all': '72025|72061|72129|72127|72139|72007',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00727',
#   'lat': '18.21142',
#   'lng': '-66.07374',
#   'city': 'Caguas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '51772',
#   'density': '885.9',
#   'county_fips': '72025',
#   'county_name': 'Caguas',
#   'county_weights': '{"72025": 100}',
#   'county_names_all': 'Caguas',
#   'county_fips_all': '72025',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00728',
#   'lat': '18.00697',
#   'lng': '-66.65995',
#   'city': 'Ponce',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '39204',
#   'density': '983.1',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 100}',
#   'county_names_all': 'Ponce',
#   'county_fips_all': '72113',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00729',
#   'lat': '18.33524',
#   'lng': '-65.88677',
#   'city': 'Canovanas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '50721',
#   'density': '547.7',
#   'county_fips': '72029',
#   'county_name': 'Canóvanas',
#   'county_weights': '{"72029": 91.45, "72087": 8.55}',
#   'county_names_all': 'Canóvanas|Loíza',
#   'county_fips_all': '72029|72087',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00730',
#   'lat': '18.03256',
#   'lng': '-66.61384',
#   'city': 'Ponce',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '29075',
#   'density': '1691.3',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 100}',
#   'county_names_all': 'Ponce',
#   'county_fips_all': '72113',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00731',
#   'lat': '18.09914',
#   'lng': '-66.63279',
#   'city': 'Ponce',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '12108',
#   'density': '95.5',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 97.12, "72001": 2.88}',
#   'county_names_all': 'Ponce|Adjuntas',
#   'county_fips_all': '72113|72001',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00735',
#   'lat': '18.2525',
#   'lng': '-65.67534',
#   'city': 'Ceiba',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '11593',
#   'density': '163.5',
#   'county_fips': '72037',
#   'county_name': 'Ceiba',
#   'county_weights': '{"72037": 94.61, "72103": 5.39}',
#   'county_names_all': 'Ceiba|Naguabo',
#   'county_fips_all': '72037|72103',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00736',
#   'lat': '18.10736',
#   'lng': '-66.14994',
#   'city': 'Cayey',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '45773',
#   'density': '321.9',
#   'county_fips': '72035',
#   'county_name': 'Cayey',
#   'county_weights': '{"72035": 92.46, "72041": 7.54}',
#   'county_names_all': 'Cayey|Cidra',
#   'county_fips_all': '72035|72041',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00738',
#   'lat': '18.31793',
#   'lng': '-65.66793',
#   'city': 'Fajardo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '28329',
#   'density': '369.3',
#   'county_fips': '72053',
#   'county_name': 'Fajardo',
#   'county_weights': '{"72053": 99.59, "72037": 0.41}',
#   'county_names_all': 'Fajardo|Ceiba',
#   'county_fips_all': '72053|72037',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00739',
#   'lat': '18.17543',
#   'lng': '-66.16198',
#   'city': 'Cidra',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '35801',
#   'density': '449.2',
#   'county_fips': '72041',
#   'county_name': 'Cidra',
#   'county_weights': '{"72041": 100}',
#   'county_names_all': 'Cidra',
#   'county_fips_all': '72041',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00740',
#   'lat': '18.33251',
#   'lng': '-65.63419',
#   'city': 'Puerto Real',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1934',
#   'density': '1788.4',
#   'county_fips': '72053',
#   'county_name': 'Fajardo',
#   'county_weights': '{"72053": 100}',
#   'county_names_all': 'Fajardo',
#   'county_fips_all': '72053',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00741',
#   'lat': '18.16569',
#   'lng': '-65.75506',
#   'city': 'Punta Santiago',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '3911',
#   'density': '663.3',
#   'county_fips': '72069',
#   'county_name': 'Humacao',
#   'county_weights': '{"72069": 100}',
#   'county_names_all': 'Humacao',
#   'county_fips_all': '72069',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00745',
#   'lat': '18.3466',
#   'lng': '-65.81382',
#   'city': 'Rio Grande',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '49472',
#   'density': '314.4',
#   'county_fips': '72119',
#   'county_name': 'Río Grande',
#   'county_weights': '{"72119": 99.78, "72029": 0.22}',
#   'county_names_all': 'Río Grande|Canóvanas',
#   'county_fips_all': '72119|72029',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00751',
#   'lat': '18.01205',
#   'lng': '-66.25871',
#   'city': 'Salinas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '20662',
#   'density': '131.4',
#   'county_fips': '72123',
#   'county_name': 'Salinas',
#   'county_weights': '{"72123": 99.83, "72035": 0.17}',
#   'county_names_all': 'Salinas|Cayey',
#   'county_fips_all': '72123|72035',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00754',
#   'lat': '18.1447',
#   'lng': '-65.97565',
#   'city': 'San Lorenzo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '36309',
#   'density': '280.4',
#   'county_fips': '72129',
#   'county_name': 'San Lorenzo',
#   'county_weights': '{"72129": 100}',
#   'county_names_all': 'San Lorenzo',
#   'county_fips_all': '72129',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00757',
#   'lat': '17.9933',
#   'lng': '-66.39056',
#   'city': 'Santa Isabel',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '21474',
#   'density': '255.6',
#   'county_fips': '72133',
#   'county_name': 'Santa Isabel',
#   'county_weights': '{"72133": 100}',
#   'county_names_all': 'Santa Isabel',
#   'county_fips_all': '72133',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00765',
#   'lat': '18.12365',
#   'lng': '-65.43013',
#   'city': 'Vieques',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '8402',
#   'density': '68.6',
#   'county_fips': '72147',
#   'county_name': 'Vieques',
#   'county_weights': '{"72147": 100}',
#   'county_names_all': 'Vieques',
#   'county_fips_all': '72147',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00766',
#   'lat': '18.13039',
#   'lng': '-66.4757',
#   'city': 'Villalba',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '22187',
#   'density': '224.4',
#   'county_fips': '72149',
#   'county_name': 'Villalba',
#   'county_weights': '{"72149": 93.48, "72107": 6.52}',
#   'county_names_all': 'Villalba|Orocovis',
#   'county_fips_all': '72149|72107',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00767',
#   'lat': '18.07033',
#   'lng': '-65.89618',
#   'city': 'Yabucoa',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '32867',
#   'density': '230.0',
#   'county_fips': '72151',
#   'county_name': 'Yabucoa',
#   'county_weights': '{"72151": 99.33, "72069": 0.67}',
#   'county_names_all': 'Yabucoa|Humacao',
#   'county_fips_all': '72151|72069',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00769',
#   'lat': '18.09459',
#   'lng': '-66.3607',
#   'city': 'Coamo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '38500',
#   'density': '192.9',
#   'county_fips': '72043',
#   'county_name': 'Coamo',
#   'county_weights': '{"72043": 98.05, "72133": 1.95}',
#   'county_names_all': 'Coamo|Santa Isabel',
#   'county_fips_all': '72043|72133',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00771',
#   'lat': '18.18797',
#   'lng': '-65.86916',
#   'city': 'Las Piedras',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '36388',
#   'density': '418.1',
#   'county_fips': '72085',
#   'county_name': 'Las Piedras',
#   'county_weights': '{"72085": 99.0, "72069": 1.0}',
#   'county_names_all': 'Las Piedras|Humacao',
#   'county_fips_all': '72085|72069',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00772',
#   'lat': '18.43048',
#   'lng': '-65.90377',
#   'city': 'Loiza',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '18919',
#   'density': '447.0',
#   'county_fips': '72087',
#   'county_name': 'Loíza',
#   'county_weights': '{"72087": 100}',
#   'county_names_all': 'Loíza',
#   'county_fips_all': '72087',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00773',
#   'lat': '18.34073',
#   'lng': '-65.72756',
#   'city': 'Luquillo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '17924',
#   'density': '287.2',
#   'county_fips': '72089',
#   'county_name': 'Luquillo',
#   'county_weights': '{"72089": 100}',
#   'county_names_all': 'Luquillo',
#   'county_fips_all': '72089',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00775',
#   'lat': '18.31387',
#   'lng': '-65.28618',
#   'city': 'Culebra',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1326',
#   'density': '44.0',
#   'county_fips': '72049',
#   'county_name': 'Culebra',
#   'county_weights': '{"72049": 100}',
#   'county_names_all': 'Culebra',
#   'county_fips_all': '72049',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00777',
#   'lat': '18.22365',
#   'lng': '-65.90904',
#   'city': 'Juncos',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '39580',
#   'density': '569.1',
#   'county_fips': '72077',
#   'county_name': 'Juncos',
#   'county_weights': '{"72077": 98.49, "72129": 0.82, "72085": 0.43, "72029": 0.14, "72063": 0.12}',
#   'county_names_all': 'Juncos|San Lorenzo|Las Piedras|Canóvanas|Gurabo',
#   'county_fips_all': '72077|72129|72085|72029|72063',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00778',
#   'lat': '18.26319',
#   'lng': '-65.97938',
#   'city': 'Gurabo',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '46720',
#   'density': '611.0',
#   'county_fips': '72063',
#   'county_name': 'Gurabo',
#   'county_weights': '{"72063": 94.08, "72129": 5.92}',
#   'county_names_all': 'Gurabo|San Lorenzo',
#   'county_fips_all': '72063|72129',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00780',
#   'lat': '18.09998',
#   'lng': '-66.57032',
#   'city': 'Coto Laurel',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '10887',
#   'density': '219.7',
#   'county_fips': '72113',
#   'county_name': 'Ponce',
#   'county_weights': '{"72113": 98.13, "72075": 1.87}',
#   'county_names_all': 'Ponce|Juana Díaz',
#   'county_fips_all': '72113|72075',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00782',
#   'lat': '18.22501',
#   'lng': '-66.22452',
#   'city': 'Comerio',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '17310',
#   'density': '238.9',
#   'county_fips': '72045',
#   'county_name': 'Comerío',
#   'county_weights': '{"72045": 97.39, "72019": 2.61}',
#   'county_names_all': 'Comerío|Barranquitas',
#   'county_fips_all': '72045|72019',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00783',
#   'lat': '18.30348',
#   'lng': '-66.32851',
#   'city': 'Corozal',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '32372',
#   'density': '296.8',
#   'county_fips': '72047',
#   'county_name': 'Corozal',
#   'county_weights': '{"72047": 99.06, "72019": 0.94}',
#   'county_names_all': 'Corozal|Barranquitas',
#   'county_fips_all': '72047|72019',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00784',
#   'lat': '18.00558',
#   'lng': '-66.13651',
#   'city': 'Guayama',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '38894',
#   'density': '225.0',
#   'county_fips': '72057',
#   'county_name': 'Guayama',
#   'county_weights': '{"72057": 97.29, "72035": 1.53, "72109": 1.18}',
#   'county_names_all': 'Guayama|Cayey|Patillas',
#   'county_fips_all': '72057|72035|72109',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00786',
#   'lat': '18.1357',
#   'lng': '-66.22881',
#   'city': 'La Plata',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '72009',
#   'county_name': 'Aibonito',
#   'county_weights': '{"72009": 100}',
#   'county_names_all': 'Aibonito',
#   'county_fips_all': '72009',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00791',
#   'lat': '18.14391',
#   'lng': '-65.81398',
#   'city': 'Humacao',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '47675',
#   'density': '431.7',
#   'county_fips': '72069',
#   'county_name': 'Humacao',
#   'county_weights': '{"72069": 97.88, "72085": 1.16, "72151": 0.96}',
#   'county_names_all': 'Humacao|Las Piedras|Yabucoa',
#   'county_fips_all': '72069|72085|72151',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00794',
#   'lat': '18.19934',
#   'lng': '-66.31179',
#   'city': 'Barranquitas',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '28088',
#   'density': '316.0',
#   'county_fips': '72019',
#   'county_name': 'Barranquitas',
#   'county_weights': '{"72019": 96.51, "72043": 3.49}',
#   'county_names_all': 'Barranquitas|Coamo',
#   'county_fips_all': '72019|72043',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00795',
#   'lat': '18.05128',
#   'lng': '-66.49485',
#   'city': 'Juana Diaz',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '43475',
#   'density': '281.0',
#   'county_fips': '72075',
#   'county_name': 'Juana Díaz',
#   'county_weights': '{"72075": 100}',
#   'county_names_all': 'Juana Díaz',
#   'county_fips_all': '72075',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/Puerto_Rico'},
#  {'zip': '00802',
#   'lat': '18.34349',
#   'lng': '-64.9287',
#   'city': 'St Thomas',
#   'state_id': 'VI',
#   'state_name': 'Virgin Islands',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '78030',
#   'county_name': 'St. Thomas',
#   'county_weights': '{"78030": 100}',
#   'county_names_all': 'St. Thomas',
#   'county_fips_all': '78030',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/St_Thomas'},
#  {'zip': '00820',
#   'lat': '17.7388',
#   'lng': '-64.70695',
#   'city': 'Christiansted',
#   'state_id': 'VI',
#   'state_name': 'Virgin Islands',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '78010',
#   'county_name': 'St. Croix',
#   'county_weights': '{"78010": 100}',
#   'county_names_all': 'St. Croix',
#   'county_fips_all': '78010',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/St_Thomas'},
#  {'zip': '00830',
#   'lat': '18.33857',
#   'lng': '-64.73802',
#   'city': 'St John',
#   'state_id': 'VI',
#   'state_name': 'Virgin Islands',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '78020',
#   'county_name': 'St. John',
#   'county_weights': '{"78020": 100}',
#   'county_names_all': 'St. John',
#   'county_fips_all': '78020',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/St_Thomas'},
#  {'zip': '00840',
#   'lat': '17.72649',
#   'lng': '-64.84717',
#   'city': 'Frederiksted',
#   'state_id': 'VI',
#   'state_name': 'Virgin Islands',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '78010',
#   'county_name': 'St. Croix',
#   'county_weights': '{"78010": 100}',
#   'county_names_all': 'St. Croix',
#   'county_fips_all': '78010',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/St_Thomas'},
#  {'zip': '00850',
#   'lat': '17.72763',
#   'lng': '-64.79122',
#   'city': 'Kingshill',
#   'state_id': 'VI',
#   'state_name': 'Virgin Islands',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '78010',
#   'county_name': 'St. Croix',
#   'county_weights': '{"78010": 100}',
#   'county_names_all': 'St. Croix',
#   'county_fips_all': '78010',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/St_Thomas'},
#  {'zip': '00851',
#   'lat': '17.74757',
#   'lng': '-64.78737',
#   'city': 'Kingshill',
#   'state_id': 'VI',
#   'state_name': 'Virgin Islands',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '',
#   'density': '',
#   'county_fips': '78010',
#   'county_name': 'St. Croix',
#   'county_weights': '{"78010": 100}',
#   'county_names_all': 'St. Croix',
#   'county_fips_all': '78010',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/St_Thomas'},
#  {'zip': '00901',
#   'lat': '18.46478',
#   'lng': '-66.10277',
#   'city': 'San Juan',
#   'state_id': 'PR',
#   'state_name': 'Puerto Rico',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
# ...
#   'density': '476.9',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03844',
#   'lat': '42.92693',
#   'lng': '-70.88603',
#   'city': 'Hampton Falls',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '2222',
#   'density': '69.3',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03845',
#   'lat': '44.10317',
#   'lng': '-71.1271',
#   'city': 'Intervale',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1213',
#   'density': '39.8',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03846',
#   'lat': '44.18445',
#   'lng': '-71.18899',
#   'city': 'Jackson',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '979',
#   'density': '5.7',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03847',
#   'lat': '44.06875',
#   'lng': '-71.12162',
#   'city': 'Kearsarge',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '376',
#   'density': '176.9',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03848',
#   'lat': '42.91562',
#   'lng': '-71.06647',
#   'city': 'Kingston',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '6330',
#   'density': '123.5',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03849',
#   'lat': '43.89454',
#   'lng': '-71.13101',
#   'city': 'Madison',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1701',
#   'density': '29.5',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03850',
#   'lat': '43.69739',
#   'lng': '-71.29983',
#   'city': 'Melvin Village',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '198',
#   'density': '26.5',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03851',
#   'lat': '43.43606',
#   'lng': '-71.01633',
#   'city': 'Milton',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '4230',
#   'density': '62.1',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03852',
#   'lat': '43.4982',
#   'lng': '-70.97547',
#   'city': 'Milton Mills',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '416',
#   'density': '23.8',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03853',
#   'lat': '43.63818',
#   'lng': '-71.29371',
#   'city': 'Mirror Lake',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '673',
#   'density': '30.1',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 99.88, "33001": 0.12}',
#   'county_names_all': 'Carroll|Belknap',
#   'county_fips_all': '33003|33001',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03854',
#   'lat': '43.06558',
#   'lng': '-70.72003',
#   'city': 'New Castle',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '863',
#   'density': '412.1',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03855',
#   'lat': '43.46343',
#   'lng': '-71.14172',
#   'city': 'New Durham',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '2801',
#   'density': '26.2',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03856',
#   'lat': '43.03916',
#   'lng': '-70.96627',
#   'city': 'Newfields',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1984',
#   'density': '108.0',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03857',
#   'lat': '43.0691',
#   'lng': '-70.95164',
#   'city': 'Newmarket',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '9161',
#   'density': '280.9',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03858',
#   'lat': '42.86839',
#   'lng': '-71.04357',
#   'city': 'Newton',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '4930',
#   'density': '194.0',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03860',
#   'lat': '44.0427',
#   'lng': '-71.12422',
#   'city': 'North Conway',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '4061',
#   'density': '67.5',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03861',
#   'lat': '43.11931',
#   'lng': '-71.0068',
#   'city': 'Lee',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '4524',
#   'density': '88.5',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03862',
#   'lat': '42.97914',
#   'lng': '-70.83025',
#   'city': 'North Hampton',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '4497',
#   'density': '124.7',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03864',
#   'lat': '43.69044',
#   'lng': '-71.10631',
#   'city': 'Ossipee',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '2080',
#   'density': '20.0',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03865',
#   'lat': '42.84032',
#   'lng': '-71.09603',
#   'city': 'Plaistow',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '7724',
#   'density': '281.6',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03867',
#   'lat': '43.3031',
#   'lng': '-70.98891',
#   'city': 'Rochester',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '21739',
#   'density': '295.5',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03868',
#   'lat': '43.31879',
#   'lng': '-70.9415',
#   'city': 'Rochester',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '5544',
#   'density': '244.7',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03869',
#   'lat': '43.22092',
#   'lng': '-70.83995',
#   'city': 'Rollinsford',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '2527',
#   'density': '145.8',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03870',
#   'lat': '43.0157',
#   'lng': '-70.76052',
#   'city': 'Rye',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '5299',
#   'density': '169.8',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03871',
#   'lat': '42.9807',
#   'lng': '-70.77358',
#   'city': 'Rye Beach',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '179',
#   'density': '124.4',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03872',
#   'lat': '43.57225',
#   'lng': '-71.04249',
#   'city': 'Sanbornville',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '3875',
#   'density': '28.7',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03873',
#   'lat': '42.93321',
#   'lng': '-71.1833',
#   'city': 'Sandown',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '6328',
#   'density': '175.3',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03874',
#   'lat': '42.88689',
#   'lng': '-70.8607',
#   'city': 'Seabrook',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '8982',
#   'density': '387.6',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03875',
#   'lat': '43.89944',
#   'lng': '-71.18636',
#   'city': 'Silver Lake',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '832',
#   'density': '19.6',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03878',
#   'lat': '43.25335',
#   'lng': '-70.88555',
#   'city': 'Somersworth',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '12085',
#   'density': '475.4',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03882',
#   'lat': '43.74727',
#   'lng': '-71.04254',
#   'city': 'Effingham',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '1647',
#   'density': '17.1',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03883',
#   'lat': '43.81252',
#   'lng': '-71.30789',
#   'city': 'South Tamworth',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '282',
#   'density': '6.0',
#   'county_fips': '33003',
#   'county_name': 'Carroll',
#   'county_weights': '{"33003": 100}',
#   'county_names_all': 'Carroll',
#   'county_fips_all': '33003',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03884',
#   'lat': '43.28018',
#   'lng': '-71.14885',
#   'city': 'Strafford',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '4023',
#   'density': '31.7',
#   'county_fips': '33017',
#   'county_name': 'Strafford',
#   'county_weights': '{"33017": 100}',
#   'county_names_all': 'Strafford',
#   'county_fips_all': '33017',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  {'zip': '03885',
#   'lat': '43.01579',
#   'lng': '-70.90051',
#   'city': 'Stratham',
#   'state_id': 'NH',
#   'state_name': 'New Hampshire',
#   'zcta': 'TRUE',
#   'parent_zcta': '',
#   'population': '7430',
#   'density': '189.6',
#   'county_fips': '33015',
#   'county_name': 'Rockingham',
#   'county_weights': '{"33015": 100}',
#   'county_names_all': 'Rockingham',
#   'county_fips_all': '33015',
#   'imprecise': 'FALSE',
#   'military': 'FALSE',
#   'timezone': 'America/New_York'},
#  ...]

# %% [markdown]
# Run the code block below after running your code to check that it is correct. If you see an output of `Correct` below the block everything is correct. If you see something like `AssertionError`, then you have a mistake.

# %%
# Don't modify this code
assert 'area_code_filename' in locals()
assert type(area_code_filename) == str
assert area_code_filename == 'area-codes-usa.csv'
assert 'area_code_data' in locals()
assert type(area_code_data) == list
assert len(area_code_data) == 2766
assert type(area_code_data[0]) == dict
assert 'zip_code_data' in locals()
assert type(zip_code_data) == list
assert len(zip_code_data) == 33788
assert type(zip_code_data[0]) == dict
print('Correct')
# Out:
# Correct

# %% [markdown]
# # Combining Data
# Now that you have hopefully read in the files successfully, we will try to combine the area code and zip code data into a single dictionary.
# 1. Create an empty dictionary called `city_state_to_zips`. This will map a tuple of city name and state code for example `('Davis','CA')` to a list of zip codes such as `['95616','95618']`.
# 1. Iterate through the `zip_code_data` and in the loop do the following:
#   1. Create a tuple composed of the city name `'city'` and state code `'state_id'` from the zip code dictionaries that will be used as a key in the `city_state_to_zips` dictionary.
#   1. If the tuple is `not in` the `city_state_to_zips` dictionary, then assign the value of that tuple to an empty `list()`. This will allow for appending the zip codes in the next step.
#   1. Append the zip code `'zip'` from the zip code dictionary to the list for the city/state in the `city_state_to_zips` dictionary using the `.append()` method.
# 1. If you print the zip codes for Davis, CA with `print(city_state_to_zips[('Davis','CA')])` you should see `['95616', '95618']`.
# 1. Create an empty dictionary called `area_code_to_zips`. This will map area codes to a list of zip codes.
# 1. Iterate through the `area_code_data` and in the loop do the following:
#   1. If the `'area-code'` is `not in` the `area_code_to_zips` dictionary, dictionary, then assign the value of that tuple to an empty `list()`. This will allow for extend the list of zip codes in the next step.
#   1. Create a tuple composed of the city name `'city'` and state code from the area code dictionaries that will be used as a key in the `city_state_to_zips` dictionary. The area code dictionaries only have state name `'state'`. Use the `state_name_to_code` dictionary to convert the state naem to state code.
#   1. If the tuple is `in` the `city_state_to_zips` dictionary, then extend the `area_code_to_zips` zip code list with the list of zips from `city_state_to_zips` using teh `.extend()` method.
# 1. If you print out the sorted zip codes for '530' with `print(sorted(area_code_to_zips['530']))` you should see something like `['95616', '95618', '95695', '95776', '95926', '95928', '95929', '95969', ...`
# 1. Verify your code works with the test block afterward.

# %%
area_code_data
# Out:
# [{'area-code': '201',
#   'city': 'Bayonne',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.66871',
#   'longitude': '-74.11431'},
#  {'area-code': '201',
#   'city': 'Bergenfield',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.9276',
#   'longitude': '-73.99736'},
#  {'area-code': '201',
#   'city': 'Cliffside Park',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.82149',
#   'longitude': '-73.98764'},
#  {'area-code': '201',
#   'city': 'Englewood',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.89288',
#   'longitude': '-73.97264'},
#  {'area-code': '201',
#   'city': 'Fair Lawn',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.94038',
#   'longitude': '-74.13181'},
#  {'area-code': '201',
#   'city': 'Fort Lee',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.85093',
#   'longitude': '-73.97014'},
#  {'area-code': '201',
#   'city': 'Hackensack',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.88593',
#   'longitude': '-74.04347'},
#  {'area-code': '201',
#   'city': 'Hoboken',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.74399',
#   'longitude': '-74.03236'},
#  {'area-code': '201',
#   'city': 'Jersey City',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.72816',
#   'longitude': '-74.07764'},
#  {'area-code': '201',
#   'city': 'Kearny',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.76843',
#   'longitude': '-74.14542'},
#  {'area-code': '201',
#   'city': 'North Bergen',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.80427',
#   'longitude': '-74.01208'},
#  {'area-code': '201',
#   'city': 'Paramus',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.94454',
#   'longitude': '-74.07542'},
#  {'area-code': '201',
#   'city': 'Ridgewood',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.97926',
#   'longitude': '-74.11653'},
#  {'area-code': '201',
#   'city': 'Teaneck',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.8976',
#   'longitude': '-74.01597'},
#  {'area-code': '201',
#   'city': 'Union City',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.77955',
#   'longitude': '-74.02375'},
#  {'area-code': '201',
#   'city': 'West New York',
#   'state': 'New Jersey',
#   'country': 'US',
#   'latitude': '40.78788',
#   'longitude': '-74.01431'},
#  {'area-code': '202',
#   'city': 'Washington',
#   'state': 'District of Columbia',
#   'country': 'US',
#   'latitude': '38.89511',
#   'longitude': '-77.03637'},
#  {'area-code': '203',
#   'city': 'Bridgeport',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.16704',
#   'longitude': '-73.20483'},
#  {'area-code': '203',
#   'city': 'Danbury',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.39482',
#   'longitude': '-73.45401'},
#  {'area-code': '203',
#   'city': 'East Haven',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.27621',
#   'longitude': '-72.86843'},
#  {'area-code': '203',
#   'city': 'Meriden',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.53815',
#   'longitude': '-72.80704'},
#  {'area-code': '203',
#   'city': 'Milford',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.22232',
#   'longitude': '-73.0565'},
#  {'area-code': '203',
#   'city': 'Naugatuck',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.48593',
#   'longitude': '-73.05066'},
#  {'area-code': '203',
#   'city': 'New Haven',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.30815',
#   'longitude': '-72.92816'},
#  {'area-code': '203',
#   'city': 'North Haven',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.39093',
#   'longitude': '-72.85954'},
#  {'area-code': '203',
#   'city': 'Norwalk',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.1176',
#   'longitude': '-73.4079'},
#  {'area-code': '203',
#   'city': 'Shelton',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.31649',
#   'longitude': '-73.09316'},
#  {'area-code': '203',
#   'city': 'Stamford',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.05343',
#   'longitude': '-73.53873'},
#  {'area-code': '203',
#   'city': 'Stratford',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.18454',
#   'longitude': '-73.13317'},
#  {'area-code': '203',
#   'city': 'Trumbull',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.24287',
#   'longitude': '-73.20067'},
#  {'area-code': '203',
#   'city': 'Waterbury',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.55815',
#   'longitude': '-73.0515'},
#  {'area-code': '203',
#   'city': 'West Haven',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.27065',
#   'longitude': '-72.94705'},
#  {'area-code': '203',
#   'city': 'Westport',
#   'state': 'Connecticut',
#   'country': 'US',
#   'latitude': '41.14149',
#   'longitude': '-73.3579'},
#  {'area-code': '205',
#   'city': 'Alabaster',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.24428',
#   'longitude': '-86.81638'},
#  {'area-code': '205',
#   'city': 'Bessemer',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.40178',
#   'longitude': '-86.95444'},
#  {'area-code': '205',
#   'city': 'Birmingham',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.52066',
#   'longitude': '-86.80249'},
#  {'area-code': '205',
#   'city': 'Center Point',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.64566',
#   'longitude': '-86.6836'},
#  {'area-code': '205',
#   'city': 'Homewood',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.47177',
#   'longitude': '-86.80082'},
#  {'area-code': '205',
#   'city': 'Hoover',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.40539',
#   'longitude': '-86.81138'},
#  {'area-code': '205',
#   'city': 'Mountain Brook',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.50094',
#   'longitude': '-86.75221'},
#  {'area-code': '205',
#   'city': 'Tuscaloosa',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.20984',
#   'longitude': '-87.56917'},
#  {'area-code': '205',
#   'city': 'Vestavia Hills',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.44872',
#   'longitude': '-86.78777'},
#  {'area-code': '206',
#   'city': 'Bainbridge Island',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.62621',
#   'longitude': '-122.52124'},
#  {'area-code': '206',
#   'city': 'Burien',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.47038',
#   'longitude': '-122.34679'},
#  {'area-code': '206',
#   'city': 'Des Moines',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.40177',
#   'longitude': '-122.32429'},
#  {'area-code': '206',
#   'city': 'Mercer Island',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.57065',
#   'longitude': '-122.22207'},
#  {'area-code': '206',
#   'city': 'Seattle',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.60621',
#   'longitude': '-122.33207'},
#  {'area-code': '206',
#   'city': 'Shoreline',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.75565',
#   'longitude': '-122.34152'},
#  {'area-code': '206',
#   'city': 'White Center',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.51732',
#   'longitude': '-122.35485'},
#  {'area-code': '207',
#   'city': 'Auburn',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '44.09785',
#   'longitude': '-70.23117'},
#  {'area-code': '207',
#   'city': 'Augusta',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '44.31062',
#   'longitude': '-69.77949'},
#  {'area-code': '207',
#   'city': 'Bangor',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '44.80118',
#   'longitude': '-68.77781'},
#  {'area-code': '207',
#   'city': 'Biddeford',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '43.49258',
#   'longitude': '-70.45338'},
#  {'area-code': '207',
#   'city': 'Brunswick',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '43.91452',
#   'longitude': '-69.96533'},
#  {'area-code': '207',
#   'city': 'Lewiston',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '44.10035',
#   'longitude': '-70.21478'},
#  {'area-code': '207',
#   'city': 'South Portland',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '43.64147',
#   'longitude': '-70.24088'},
#  {'area-code': '207',
#   'city': 'South Portland',
#   'state': 'Maine',
#   'country': 'US',
#   'latitude': '43.64147',
#   'longitude': '-70.24088'},
#  {'area-code': '208',
#   'city': 'Boise',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '43.6135',
#   'longitude': '-116.20345'},
#  {'area-code': '208',
#   'city': 'Caldwell',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '43.66294',
#   'longitude': '-116.68736'},
#  {'area-code': '208',
#   'city': "Coeur d'Alene",
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '47.67768',
#   'longitude': '-116.78047'},
#  {'area-code': '208',
#   'city': 'Idaho Falls',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '43.46658',
#   'longitude': '-112.03414'},
#  {'area-code': '208',
#   'city': 'Lewiston',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '46.41655',
#   'longitude': '-117.01766'},
#  {'area-code': '208',
#   'city': 'Meridian',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '43.61211',
#   'longitude': '-116.39151'},
#  {'area-code': '208',
#   'city': 'Moscow',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '46.73239',
#   'longitude': '-117.00017'},
#  {'area-code': '208',
#   'city': 'Nampa',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '43.54072',
#   'longitude': '-116.56346'},
#  {'area-code': '208',
#   'city': 'Pocatello',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '42.8713',
#   'longitude': '-112.44553'},
#  {'area-code': '208',
#   'city': 'Twin Falls',
#   'state': 'Idaho',
#   'country': 'US',
#   'latitude': '42.56297',
#   'longitude': '-114.46087'},
#  {'area-code': '209',
#   'city': 'Atwater',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.34772',
#   'longitude': '-120.60908'},
#  {'area-code': '209',
#   'city': 'Ceres',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.59493',
#   'longitude': '-120.95771'},
#  {'area-code': '209',
#   'city': 'Lodi',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '38.1302',
#   'longitude': '-121.27245'},
#  {'area-code': '209',
#   'city': 'Los Banos',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.05828',
#   'longitude': '-120.84992'},
#  {'area-code': '209',
#   'city': 'Manteca',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.79743',
#   'longitude': '-121.21605'},
#  {'area-code': '209',
#   'city': 'Merced',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.30216',
#   'longitude': '-120.48297'},
#  {'area-code': '209',
#   'city': 'West Modesto',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.61754',
#   'longitude': '-121.03914'},
#  {'area-code': '209',
#   'city': 'Stockton',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.9577',
#   'longitude': '-121.29078'},
#  {'area-code': '209',
#   'city': 'Tracy',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.73987',
#   'longitude': '-121.42618'},
#  {'area-code': '209',
#   'city': 'Turlock',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '37.49466',
#   'longitude': '-120.84659'},
#  {'area-code': '210',
#   'city': 'San Antonio',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.42412',
#   'longitude': '-98.49363'},
#  {'area-code': '212',
#   'city': 'New York City',
#   'state': 'New York',
#   'country': 'US',
#   'latitude': '40.71427',
#   'longitude': '-74.00597'},
#  {'area-code': '212',
#   'city': 'New York City',
#   'state': 'New York',
#   'country': 'US',
#   'latitude': '40.71427',
#   'longitude': '-74.00597'},
#  {'area-code': '213',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '34.05223',
#   'longitude': '-118.24368'},
#  {'area-code': '214',
#   'city': 'Allen',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.10317',
#   'longitude': '-96.67055'},
#  {'area-code': '214',
#   'city': 'Arlington',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.73569',
#   'longitude': '-97.10807'},
#  {'area-code': '214',
#   'city': 'Carrollton',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.95373',
#   'longitude': '-96.89028'},
#  {'area-code': '214',
#   'city': 'Cedar Hill',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.58847',
#   'longitude': '-96.95612'},
#  {'area-code': '214',
#   'city': 'Coppell',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.95457',
#   'longitude': '-97.01501'},
#  {'area-code': '214',
#   'city': 'Dallas',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.78306',
#   'longitude': '-96.80667'},
#  {'area-code': '214',
#   'city': 'DeSoto',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.58986',
#   'longitude': '-96.85695'},
#  {'area-code': '214',
#   'city': 'Duncanville',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.6518',
#   'longitude': '-96.90834'},
#  {'area-code': '214',
#   'city': 'Farmers Branch',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.92651',
#   'longitude': '-96.89612'},
#  {'area-code': '214',
#   'city': 'Flower Mound',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.01457',
#   'longitude': '-97.09696'},
#  {'area-code': '214',
#   'city': 'Frisco',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.15067',
#   'longitude': '-96.82361'},
#  {'area-code': '214',
#   'city': 'Garland',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.91262',
#   'longitude': '-96.63888'},
#  {'area-code': '214',
#   'city': 'Grand Prairie',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.74596',
#   'longitude': '-96.99778'},
#  {'area-code': '214',
#   'city': 'Irving',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.81402',
#   'longitude': '-96.94889'},
#  {'area-code': '214',
#   'city': 'Lancaster',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.59208',
#   'longitude': '-96.75611'},
#  {'area-code': '214',
#   'city': 'Lewisville',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.04623',
#   'longitude': '-96.99417'},
#  {'area-code': '214',
#   'city': 'McKinney',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.19762',
#   'longitude': '-96.61527'},
#  {'area-code': '214',
#   'city': 'Mesquite',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.7668',
#   'longitude': '-96.59916'},
#  {'area-code': '214',
#   'city': 'Plano',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.01984',
#   'longitude': '-96.69889'},
#  {'area-code': '214',
#   'city': 'Richardson',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.94818',
#   'longitude': '-96.72972'},
#  {'area-code': '214',
#   'city': 'Rowlett',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.9029',
#   'longitude': '-96.56388'},
#  {'area-code': '214',
#   'city': 'The Colony',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.08901',
#   'longitude': '-96.88639'},
#  {'area-code': '214',
#   'city': 'University Park',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.85013',
#   'longitude': '-96.80028'},
#  {'area-code': '214',
#   'city': 'Waxahachie',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.38653',
#   'longitude': '-96.84833'},
#  {'area-code': '215',
#   'city': 'Levittown',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '40.15511',
#   'longitude': '-74.82877'},
#  {'area-code': '215',
#   'city': 'Philadelphia',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '39.95233',
#   'longitude': '-75.16379'},
#  {'area-code': '216',
#   'city': 'Brook Park',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.39838',
#   'longitude': '-81.80458'},
#  {'area-code': '216',
#   'city': 'East Cleveland',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.53311',
#   'longitude': '-81.57901'},
#  {'area-code': '216',
#   'city': 'Cleveland Heights',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.52005',
#   'longitude': '-81.55624'},
#  {'area-code': '216',
#   'city': 'East Cleveland',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.53311',
#   'longitude': '-81.57901'},
#  {'area-code': '216',
#   'city': 'South Euclid',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.52311',
#   'longitude': '-81.51846'},
#  {'area-code': '216',
#   'city': 'Garfield Heights',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.417',
#   'longitude': '-81.60596'},
#  {'area-code': '216',
#   'city': 'Lakewood',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.48199',
#   'longitude': '-81.79819'},
#  {'area-code': '216',
#   'city': 'Maple Heights',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.41533',
#   'longitude': '-81.56596'},
#  {'area-code': '216',
#   'city': 'Parma',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.40477',
#   'longitude': '-81.72291'},
#  {'area-code': '216',
#   'city': 'Shaker Heights',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.47394',
#   'longitude': '-81.53707'},
#  {'area-code': '216',
#   'city': 'South Euclid',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.52311',
#   'longitude': '-81.51846'},
#  {'area-code': '217',
#   'city': 'Champaign',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '40.11642',
#   'longitude': '-88.24338'},
#  {'area-code': '217',
#   'city': 'Charleston',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '39.49615',
#   'longitude': '-88.17615'},
#  {'area-code': '217',
#   'city': 'Danville',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '40.12448',
#   'longitude': '-87.63002'},
#  {'area-code': '217',
#   'city': 'Decatur',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '39.84031',
#   'longitude': '-88.9548'},
#  {'area-code': '217',
#   'city': 'Quincy',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '39.9356',
#   'longitude': '-91.40987'},
#  {'area-code': '217',
#   'city': 'Springfield',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '39.80172',
#   'longitude': '-89.64371'},
#  {'area-code': '217',
#   'city': 'Urbana',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '40.11059',
#   'longitude': '-88.20727'},
#  {'area-code': '218',
#   'city': 'Andover',
#   'state': 'Minnesota',
#   'country': 'US',
#   'latitude': '45.2333',
#   'longitude': '-93.29134'},
#  {'area-code': '218',
#   'city': 'Duluth',
#   'state': 'Minnesota',
#   'country': 'US',
#   'latitude': '46.78327',
#   'longitude': '-92.10658'},
#  {'area-code': '218',
#   'city': 'Moorhead',
#   'state': 'Minnesota',
#   'country': 'US',
#   'latitude': '46.87386',
#   'longitude': '-96.76951'},
#  {'area-code': '219',
#   'city': 'East Chicago',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.6392',
#   'longitude': '-87.45476'},
#  {'area-code': '219',
#   'city': 'Gary',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.59337',
#   'longitude': '-87.34643'},
#  {'area-code': '219',
#   'city': 'Hammond',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.58337',
#   'longitude': '-87.50004'},
#  {'area-code': '219',
#   'city': 'Highland',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.55365',
#   'longitude': '-87.45198'},
#  {'area-code': '219',
#   'city': 'Hobart',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.53226',
#   'longitude': '-87.25504'},
#  {'area-code': '219',
#   'city': 'LaPorte',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.6106',
#   'longitude': '-86.72252'},
#  {'area-code': '219',
#   'city': 'Merrillville',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.48281',
#   'longitude': '-87.33281'},
#  {'area-code': '219',
#   'city': 'Michigan City',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.70754',
#   'longitude': '-86.89503'},
#  {'area-code': '219',
#   'city': 'Munster',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.56448',
#   'longitude': '-87.51254'},
#  {'area-code': '219',
#   'city': 'Portage',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.57587',
#   'longitude': '-87.17615'},
#  {'area-code': '219',
#   'city': 'Schererville',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.47892',
#   'longitude': '-87.45476'},
#  {'area-code': '219',
#   'city': 'Valparaiso',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.47309',
#   'longitude': '-87.06114'},
#  {'area-code': '220',
#   'city': 'Athens',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '39.32924',
#   'longitude': '-82.10126'},
#  {'area-code': '220',
#   'city': 'Chillicothe',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '39.33312',
#   'longitude': '-82.9824'},
#  {'area-code': '220',
#   'city': 'Delaware',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.29867',
#   'longitude': '-83.06797'},
#  {'area-code': '220',
#   'city': 'Lancaster',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '39.71368',
#   'longitude': '-82.59933'},
#  {'area-code': '220',
#   'city': 'Marion',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.58867',
#   'longitude': '-83.12852'},
#  {'area-code': '220',
#   'city': 'Newark',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.05812',
#   'longitude': '-82.40126'},
#  {'area-code': '220',
#   'city': 'Portsmouth',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '38.73174',
#   'longitude': '-82.99767'},
#  {'area-code': '220',
#   'city': 'Zanesville',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '39.94035',
#   'longitude': '-82.01319'},
#  {'area-code': '224',
#   'city': 'Algonquin',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.16558',
#   'longitude': '-88.29425'},
#  {'area-code': '224',
#   'city': 'Arlington Heights',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.08836',
#   'longitude': '-87.98063'},
#  {'area-code': '224',
#   'city': 'Buffalo Grove',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.15141',
#   'longitude': '-87.95979'},
#  {'area-code': '224',
#   'city': 'Carpentersville',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.12114',
#   'longitude': '-88.25786'},
#  {'area-code': '224',
#   'city': 'Des Plaines',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.03336',
#   'longitude': '-87.8834'},
#  {'area-code': '224',
#   'city': 'South Elgin',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '41.99419',
#   'longitude': '-88.2923'},
#  {'area-code': '224',
#   'city': 'Elk Grove Village',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.00392',
#   'longitude': '-87.97035'},
#  {'area-code': '224',
#   'city': 'Evanston',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.04114',
#   'longitude': '-87.69006'},
#  {'area-code': '224',
#   'city': 'Glenview',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.06975',
#   'longitude': '-87.78784'},
#  {'area-code': '224',
#   'city': 'Gurnee',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.3703',
#   'longitude': '-87.90202'},
#  {'area-code': '224',
#   'city': 'Highland Park',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.18169',
#   'longitude': '-87.80034'},
#  {'area-code': '224',
#   'city': 'Hoffman Estates',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.04281',
#   'longitude': '-88.0798'},
#  {'area-code': '224',
#   'city': 'Lake Forest',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.25863',
#   'longitude': '-87.84063'},
#  {'area-code': '224',
#   'city': 'Lake in the Hills',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.18169',
#   'longitude': '-88.33036'},
#  {'area-code': '224',
#   'city': 'Libertyville',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.28308',
#   'longitude': '-87.95313'},
#  {'area-code': '224',
#   'city': 'Morton Grove',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.04059',
#   'longitude': '-87.78256'},
#  {'area-code': '224',
#   'city': 'Mount Prospect',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.06642',
#   'longitude': '-87.93729'},
#  {'area-code': '224',
#   'city': 'Mundelein',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.26308',
#   'longitude': '-88.00397'},
#  {'area-code': '224',
#   'city': 'Niles',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.01892',
#   'longitude': '-87.80284'},
#  {'area-code': '224',
#   'city': 'North Chicago',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.32558',
#   'longitude': '-87.84118'},
#  {'area-code': '224',
#   'city': 'Northbrook',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.12753',
#   'longitude': '-87.82895'},
#  {'area-code': '224',
#   'city': 'Palatine',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.1103',
#   'longitude': '-88.03424'},
#  {'area-code': '224',
#   'city': 'Park Ridge',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.01114',
#   'longitude': '-87.84062'},
#  {'area-code': '224',
#   'city': 'Rolling Meadows',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.08419',
#   'longitude': '-88.01313'},
#  {'area-code': '224',
#   'city': 'Round Lake Beach',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.37169',
#   'longitude': '-88.09008'},
#  {'area-code': '224',
#   'city': 'Schaumburg',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.03336',
#   'longitude': '-88.08341'},
#  {'area-code': '224',
#   'city': 'Skokie',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.03336',
#   'longitude': '-87.73339'},
#  {'area-code': '224',
#   'city': 'Vernon Hills',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.21947',
#   'longitude': '-87.97952'},
#  {'area-code': '224',
#   'city': 'Waukegan',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.36363',
#   'longitude': '-87.84479'},
#  {'area-code': '224',
#   'city': 'Wheeling',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.13919',
#   'longitude': '-87.92896'},
#  {'area-code': '224',
#   'city': 'Wilmette',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.07225',
#   'longitude': '-87.72284'},
#  {'area-code': '224',
#   'city': 'Zion',
#   'state': 'Illinois',
#   'country': 'US',
#   'latitude': '42.44613',
#   'longitude': '-87.83285'},
#  {'area-code': '225',
#   'city': 'Baton Rouge',
#   'state': 'Louisiana',
#   'country': 'US',
#   'latitude': '30.45075',
#   'longitude': '-91.15455'},
#  {'area-code': '228',
#   'city': 'Biloxi',
#   'state': 'Mississippi',
#   'country': 'US',
#   'latitude': '30.39603',
#   'longitude': '-88.88531'},
#  {'area-code': '228',
#   'city': 'West Gulfport',
#   'state': 'Mississippi',
#   'country': 'US',
#   'latitude': '30.40409',
#   'longitude': '-89.0942'},
#  {'area-code': '228',
#   'city': 'Pascagoula',
#   'state': 'Mississippi',
#   'country': 'US',
#   'latitude': '30.36576',
#   'longitude': '-88.55613'},
#  {'area-code': '229',
#   'city': 'Albany',
#   'state': 'Georgia',
#   'country': 'US',
#   'latitude': '31.57851',
#   'longitude': '-84.15574'},
#  {'area-code': '229',
#   'city': 'Valdosta',
#   'state': 'Georgia',
#   'country': 'US',
#   'latitude': '30.83334',
#   'longitude': '-83.28032'},
#  {'area-code': '231',
#   'city': 'Muskegon',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '43.23418',
#   'longitude': '-86.24839'},
#  {'area-code': '231',
#   'city': 'Norton Shores',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '43.1689',
#   'longitude': '-86.26395'},
#  {'area-code': '231',
#   'city': 'Shelby',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.67087',
#   'longitude': '-83.03298'},
#  {'area-code': '234',
#   'city': 'Akron',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.08144',
#   'longitude': '-81.51901'},
#  {'area-code': '234',
#   'city': 'Alliance',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.91534',
#   'longitude': '-81.10593'},
#  {'area-code': '234',
#   'city': 'Austintown',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.10172',
#   'longitude': '-80.76452'},
#  {'area-code': '234',
#   'city': 'Barberton',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.01283',
#   'longitude': '-81.60512'},
#  {'area-code': '234',
#   'city': 'Boardman',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.02423',
#   'longitude': '-80.66285'},
#  {'area-code': '234',
#   'city': 'Brunswick',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.23811',
#   'longitude': '-81.8418'},
#  {'area-code': '234',
#   'city': 'North Canton',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.87589',
#   'longitude': '-81.40234'},
#  {'area-code': '234',
#   'city': 'Cuyahoga Falls',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.13394',
#   'longitude': '-81.48456'},
#  {'area-code': '234',
#   'city': 'Green',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.94589',
#   'longitude': '-81.48317'},
#  {'area-code': '234',
#   'city': 'Hudson',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.24006',
#   'longitude': '-81.44067'},
#  {'area-code': '234',
#   'city': 'Kent',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.15367',
#   'longitude': '-81.35789'},
#  {'area-code': '234',
#   'city': 'Massillon',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.79672',
#   'longitude': '-81.52151'},
#  {'area-code': '234',
#   'city': 'Medina',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.13839',
#   'longitude': '-81.86375'},
#  {'area-code': '234',
#   'city': 'Niles',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.18284',
#   'longitude': '-80.76536'},
#  {'area-code': '234',
#   'city': 'Stow',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.1595',
#   'longitude': '-81.44039'},
#  {'area-code': '234',
#   'city': 'Warren',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.23756',
#   'longitude': '-80.81842'},
#  {'area-code': '234',
#   'city': 'Wooster',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '40.80517',
#   'longitude': '-81.93646'},
#  {'area-code': '234',
#   'city': 'Youngstown',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.09978',
#   'longitude': '-80.64952'},
#  {'area-code': '239',
#   'city': 'Bonita Springs',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.33981',
#   'longitude': '-81.7787'},
#  {'area-code': '239',
#   'city': 'Cape Coral',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.56285',
#   'longitude': '-81.94953'},
#  {'area-code': '239',
#   'city': 'North Fort Myers',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.66729',
#   'longitude': '-81.88009'},
#  {'area-code': '239',
#   'city': 'Golden Gate',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.18787',
#   'longitude': '-81.69509'},
#  {'area-code': '239',
#   'city': 'Lehigh Acres',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.62535',
#   'longitude': '-81.6248'},
#  {'area-code': '239',
#   'city': 'Naples',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.14234',
#   'longitude': '-81.79596'},
#  {'area-code': '239',
#   'city': 'North Fort Myers',
#   'state': 'Florida',
#   'country': 'US',
#   'latitude': '26.66729',
#   'longitude': '-81.88009'},
#  {'area-code': '240',
#   'city': 'Aspen Hill',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.07955',
#   'longitude': '-77.07303'},
#  {'area-code': '240',
#   'city': 'North Bethesda',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.04455',
#   'longitude': '-77.11887'},
#  {'area-code': '240',
#   'city': 'Bowie',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.94278',
#   'longitude': '-76.73028'},
#  {'area-code': '240',
#   'city': 'Chillum',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.96372',
#   'longitude': '-76.99081'},
#  {'area-code': '240',
#   'city': 'Clinton',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.76511',
#   'longitude': '-76.89831'},
#  {'area-code': '240',
#   'city': 'College Park',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.98067',
#   'longitude': '-76.93692'},
#  {'area-code': '240',
#   'city': 'Cumberland',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.65287',
#   'longitude': '-78.76252'},
#  {'area-code': '240',
#   'city': 'Fairland',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.07622',
#   'longitude': '-76.95775'},
#  {'area-code': '240',
#   'city': 'Fort Washington',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.70734',
#   'longitude': '-77.02303'},
#  {'area-code': '240',
#   'city': 'Frederick',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.41427',
#   'longitude': '-77.41054'},
#  {'area-code': '240',
#   'city': 'Gaithersburg',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.14344',
#   'longitude': '-77.20137'},
#  {'area-code': '240',
#   'city': 'Germantown',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.17316',
#   'longitude': '-77.27165'},
#  {'area-code': '240',
#   'city': 'Greenbelt',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.00455',
#   'longitude': '-76.87553'},
#  {'area-code': '240',
#   'city': 'Hagerstown',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.64176',
#   'longitude': '-77.71999'},
#  {'area-code': '240',
#   'city': 'Landover',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.934',
#   'longitude': '-76.89664'},
#  {'area-code': '240',
#   'city': 'Montgomery Village',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.17677',
#   'longitude': '-77.19526'},
#  {'area-code': '240',
#   'city': 'North Bethesda',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.04455',
#   'longitude': '-77.11887'},
#  {'area-code': '240',
#   'city': 'South Laurel',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.06983',
#   'longitude': '-76.85025'},
#  {'area-code': '240',
#   'city': 'North Potomac',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.08289',
#   'longitude': '-77.26498'},
#  {'area-code': '240',
#   'city': 'Olney',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.15316',
#   'longitude': '-77.06692'},
#  {'area-code': '240',
#   'city': 'Potomac',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.01817',
#   'longitude': '-77.20859'},
#  {'area-code': '240',
#   'city': 'Rockville',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.084',
#   'longitude': '-77.15276'},
#  {'area-code': '240',
#   'city': 'Silver Spring',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.99067',
#   'longitude': '-77.02609'},
#  {'area-code': '240',
#   'city': 'South Laurel',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.06983',
#   'longitude': '-76.85025'},
#  {'area-code': '240',
#   'city': 'Saint Charles',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.60317',
#   'longitude': '-76.93858'},
#  {'area-code': '240',
#   'city': 'Suitland',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.84872',
#   'longitude': '-76.92386'},
#  {'area-code': '240',
#   'city': 'Waldorf',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.62456',
#   'longitude': '-76.93914'},
#  {'area-code': '240',
#   'city': 'White Oak',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.03983',
#   'longitude': '-76.99303'},
#  {'area-code': '248',
#   'city': 'West Bloomfield Township',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.56891',
#   'longitude': '-83.38356'},
#  {'area-code': '248',
#   'city': 'Farmington Hills',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.48531',
#   'longitude': '-83.37716'},
#  {'area-code': '248',
#   'city': 'Ferndale',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.46059',
#   'longitude': '-83.13465'},
#  {'area-code': '248',
#   'city': 'Madison Heights',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.48587',
#   'longitude': '-83.1052'},
#  {'area-code': '248',
#   'city': 'Novi',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.48059',
#   'longitude': '-83.47549'},
#  {'area-code': '248',
#   'city': 'Oak Park',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.45948',
#   'longitude': '-83.18271'},
#  {'area-code': '248',
#   'city': 'Pontiac',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.63892',
#   'longitude': '-83.29105'},
#  {'area-code': '248',
#   'city': 'Rochester Hills',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.65837',
#   'longitude': '-83.14993'},
#  {'area-code': '248',
#   'city': 'Royal Oak',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.48948',
#   'longitude': '-83.14465'},
#  {'area-code': '248',
#   'city': 'Southfield',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.47337',
#   'longitude': '-83.22187'},
#  {'area-code': '248',
#   'city': 'Troy',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.60559',
#   'longitude': '-83.14993'},
#  {'area-code': '248',
#   'city': 'Waterford',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.69303',
#   'longitude': '-83.41181'},
#  {'area-code': '248',
#   'city': 'West Bloomfield Township',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.56891',
#   'longitude': '-83.38356'},
#  {'area-code': '251',
#   'city': 'Mobile',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '30.69436',
#   'longitude': '-88.04305'},
#  {'area-code': '251',
#   'city': 'Prichard',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '30.7388',
#   'longitude': '-88.07889'},
#  {'area-code': '252',
#   'city': 'Greenville',
#   'state': 'North Carolina',
#   'country': 'US',
#   'latitude': '35.61266',
#   'longitude': '-77.36635'},
#  {'area-code': '252',
#   'city': 'Havelock',
#   'state': 'North Carolina',
#   'country': 'US',
#   'latitude': '34.87905',
#   'longitude': '-76.90133'},
#  {'area-code': '252',
#   'city': 'Kinston',
#   'state': 'North Carolina',
#   'country': 'US',
#   'latitude': '35.26266',
#   'longitude': '-77.58164'},
#  {'area-code': '252',
#   'city': 'New Bern',
#   'state': 'North Carolina',
#   'country': 'US',
#   'latitude': '35.10849',
#   'longitude': '-77.04411'},
#  {'area-code': '252',
#   'city': 'Rocky Mount',
#   'state': 'North Carolina',
#   'country': 'US',
#   'latitude': '35.93821',
#   'longitude': '-77.79053'},
#  {'area-code': '252',
#   'city': 'Wilson',
#   'state': 'North Carolina',
#   'country': 'US',
#   'latitude': '35.72127',
#   'longitude': '-77.91554'},
#  {'area-code': '253',
#   'city': 'Auburn',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.30732',
#   'longitude': '-122.22845'},
#  {'area-code': '253',
#   'city': 'East Hill-Meridian',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.41052',
#   'longitude': '-122.17369'},
#  {'area-code': '253',
#   'city': 'Federal Way',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.32232',
#   'longitude': '-122.31262'},
#  {'area-code': '253',
#   'city': 'Lakewood',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.17176',
#   'longitude': '-122.51846'},
#  {'area-code': '253',
#   'city': 'Parkland',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.15538',
#   'longitude': '-122.43401'},
#  {'area-code': '253',
#   'city': 'Puyallup',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.18538',
#   'longitude': '-122.2929'},
#  {'area-code': '253',
#   'city': 'South Hill',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.14121',
#   'longitude': '-122.27012'},
#  {'area-code': '253',
#   'city': 'Spanaway',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.10399',
#   'longitude': '-122.43457'},
#  {'area-code': '253',
#   'city': 'Tacoma',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.25288',
#   'longitude': '-122.44429'},
#  {'area-code': '253',
#   'city': 'University Place',
#   'state': 'Washington',
#   'country': 'US',
#   'latitude': '47.23565',
#   'longitude': '-122.5504'},
#  {'area-code': '254',
#   'city': 'Copperas Cove',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '31.12406',
#   'longitude': '-97.90308'},
#  {'area-code': '254',
#   'city': 'Fort Hood',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '31.13489',
#   'longitude': '-97.77561'},
#  {'area-code': '254',
#   'city': 'Killeen',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '31.11712',
#   'longitude': '-97.7278'},
#  {'area-code': '254',
#   'city': 'Temple',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '31.09823',
#   'longitude': '-97.34278'},
#  {'area-code': '254',
#   'city': 'Waco',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '31.54933',
#   'longitude': '-97.14667'},
#  {'area-code': '256',
#   'city': 'Anniston',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '33.65983',
#   'longitude': '-85.83163'},
#  {'area-code': '256',
#   'city': 'Decatur',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '34.60593',
#   'longitude': '-86.98334'},
#  {'area-code': '256',
#   'city': 'Florence',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '34.79981',
#   'longitude': '-87.67725'},
#  {'area-code': '256',
#   'city': 'Gadsden',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '34.01426',
#   'longitude': '-86.00664'},
#  {'area-code': '256',
#   'city': 'Huntsville',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '34.73037',
#   'longitude': '-86.5861'},
#  {'area-code': '256',
#   'city': 'Madison',
#   'state': 'Alabama',
#   'country': 'US',
#   'latitude': '34.69926',
#   'longitude': '-86.74833'},
#  {'area-code': '260',
#   'city': 'Fort Wayne',
#   'state': 'Indiana',
#   'country': 'US',
#   'latitude': '41.1306',
#   'longitude': '-85.12886'},
#  {'area-code': '262',
#   'city': 'Brookfield',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '43.06057',
#   'longitude': '-88.10648'},
#  {'area-code': '262',
#   'city': 'Caledonia',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '42.8078',
#   'longitude': '-87.92425'},
#  {'area-code': '262',
#   'city': 'Kenosha',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '42.58474',
#   'longitude': '-87.82119'},
#  {'area-code': '262',
#   'city': 'Menomonee Falls',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '43.1789',
#   'longitude': '-88.11731'},
#  {'area-code': '262',
#   'city': 'Mequon',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '43.2364',
#   'longitude': '-87.98453'},
#  {'area-code': '262',
#   'city': 'Muskego',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '42.90585',
#   'longitude': '-88.13898'},
#  {'area-code': '262',
#   'city': 'New Berlin',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '42.9764',
#   'longitude': '-88.10842'},
#  {'area-code': '262',
#   'city': 'Racine',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '42.72613',
#   'longitude': '-87.78285'},
#  {'area-code': '262',
#   'city': 'Waukesha',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '43.01168',
#   'longitude': '-88.23148'},
#  {'area-code': '262',
#   'city': 'West Bend',
#   'state': 'Wisconsin',
#   'country': 'US',
#   'latitude': '43.42528',
#   'longitude': '-88.18343'},
#  {'area-code': '267',
#   'city': 'Levittown',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '40.15511',
#   'longitude': '-74.82877'},
#  {'area-code': '267',
#   'city': 'Philadelphia',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '39.95233',
#   'longitude': '-75.16379'},
#  {'area-code': '269',
#   'city': 'Battle Creek',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.3173',
#   'longitude': '-85.17816'},
#  {'area-code': '269',
#   'city': 'Kalamazoo',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.29171',
#   'longitude': '-85.58723'},
#  {'area-code': '269',
#   'city': 'Portage',
#   'state': 'Michigan',
#   'country': 'US',
#   'latitude': '42.20115',
#   'longitude': '-85.58'},
#  {'area-code': '270',
#   'city': 'Bowling Green',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '36.99032',
#   'longitude': '-86.4436'},
#  {'area-code': '270',
#   'city': 'Elizabethtown',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '37.69395',
#   'longitude': '-85.85913'},
#  {'area-code': '270',
#   'city': 'Henderson',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '37.83615',
#   'longitude': '-87.59001'},
#  {'area-code': '270',
#   'city': 'Hopkinsville',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '36.86561',
#   'longitude': '-87.49117'},
#  {'area-code': '270',
#   'city': 'Owensboro',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '37.77422',
#   'longitude': '-87.11333'},
#  {'area-code': '270',
#   'city': 'Paducah',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '37.08339',
#   'longitude': '-88.60005'},
#  {'area-code': '270',
#   'city': 'Radcliff',
#   'state': 'Kentucky',
#   'country': 'US',
#   'latitude': '37.84035',
#   'longitude': '-85.94913'},
#  {'area-code': '272',
#   'city': 'Back Mountain',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '41.33591',
#   'longitude': '-75.99631'},
#  {'area-code': '272',
#   'city': 'Hazleton',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '40.95842',
#   'longitude': '-75.97465'},
#  {'area-code': '272',
#   'city': 'Scranton',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '41.40916',
#   'longitude': '-75.6649'},
#  {'area-code': '272',
#   'city': 'Wilkes-Barre',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '41.24591',
#   'longitude': '-75.88131'},
#  {'area-code': '272',
#   'city': 'Williamsport',
#   'state': 'Pennsylvania',
#   'country': 'US',
#   'latitude': '41.24119',
#   'longitude': '-77.00108'},
#  {'area-code': '276',
#   'city': 'Richmond',
#   'state': 'Virginia',
#   'country': 'US',
#   'latitude': '37.55376',
#   'longitude': '-77.46026'},
#  {'area-code': '281',
#   'city': 'Alvin',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.42385',
#   'longitude': '-95.2441'},
#  {'area-code': '281',
#   'city': 'Atascocita',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.99883',
#   'longitude': '-95.1766'},
#  {'area-code': '281',
#   'city': 'Baytown',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.7355',
#   'longitude': '-94.97743'},
#  {'area-code': '281',
#   'city': 'Channelview',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.77606',
#   'longitude': '-95.11465'},
#  {'area-code': '281',
#   'city': 'Cloverleaf',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.77828',
#   'longitude': '-95.17188'},
#  {'area-code': '281',
#   'city': 'Deer Park',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.70523',
#   'longitude': '-95.12382'},
#  {'area-code': '281',
#   'city': 'Friendswood',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.5294',
#   'longitude': '-95.20104'},
#  {'area-code': '281',
#   'city': 'South Houston',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.66301',
#   'longitude': '-95.23549'},
#  {'area-code': '281',
#   'city': 'La Porte',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.66578',
#   'longitude': '-95.01937'},
#  {'area-code': '281',
#   'city': 'League City',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.50745',
#   'longitude': '-95.09493'},
#  {'area-code': '281',
#   'city': 'Mission Bend',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.69384',
#   'longitude': '-95.66495'},
#  {'area-code': '281',
#   'city': 'Missouri City',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.61857',
#   'longitude': '-95.53772'},
#  {'area-code': '281',
#   'city': 'Pasadena',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.69106',
#   'longitude': '-95.2091'},
#  {'area-code': '281',
#   'city': 'Pearland',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.56357',
#   'longitude': '-95.28605'},
#  {'area-code': '281',
#   'city': 'Rosenberg',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.55718',
#   'longitude': '-95.80856'},
#  {'area-code': '281',
#   'city': 'Spring',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '30.07994',
#   'longitude': '-95.41716'},
#  {'area-code': '281',
#   'city': 'Sugar Land',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '29.61968',
#   'longitude': '-95.63495'},
#  {'area-code': '281',
#   'city': 'The Woodlands',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '30.15799',
#   'longitude': '-95.48938'},
#  {'area-code': '301',
#   'city': 'Aspen Hill',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.07955',
#   'longitude': '-77.07303'},
#  {'area-code': '301',
#   'city': 'North Bethesda',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.04455',
#   'longitude': '-77.11887'},
#  {'area-code': '301',
#   'city': 'Bowie',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.94278',
#   'longitude': '-76.73028'},
#  {'area-code': '301',
#   'city': 'Chillum',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.96372',
#   'longitude': '-76.99081'},
#  {'area-code': '301',
#   'city': 'Clinton',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.76511',
#   'longitude': '-76.89831'},
#  {'area-code': '301',
#   'city': 'College Park',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.98067',
#   'longitude': '-76.93692'},
#  {'area-code': '301',
#   'city': 'Cumberland',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.65287',
# ...
#  {'area-code': '434',
#   'city': 'Charlottesville',
#   'state': 'Virginia',
#   'country': 'US',
#   'latitude': '38.02931',
#   'longitude': '-78.47668'},
#  {'area-code': '434',
#   'city': 'Danville',
#   'state': 'Virginia',
#   'country': 'US',
#   'latitude': '36.58597',
#   'longitude': '-79.39502'},
#  {'area-code': '434',
#   'city': 'West Lynchburg',
#   'state': 'Virginia',
#   'country': 'US',
#   'latitude': '37.4032',
#   'longitude': '-79.17808'},
#  {'area-code': '435',
#   'city': 'Cedar City',
#   'state': 'Utah',
#   'country': 'US',
#   'latitude': '37.67748',
#   'longitude': '-113.06189'},
#  {'area-code': '435',
#   'city': 'North Logan',
#   'state': 'Utah',
#   'country': 'US',
#   'latitude': '41.76937',
#   'longitude': '-111.80467'},
#  {'area-code': '435',
#   'city': 'Saint George',
#   'state': 'Utah',
#   'country': 'US',
#   'latitude': '37.10415',
#   'longitude': '-113.58412'},
#  {'area-code': '435',
#   'city': 'Tooele',
#   'state': 'Utah',
#   'country': 'US',
#   'latitude': '40.53078',
#   'longitude': '-112.29828'},
#  {'area-code': '440',
#   'city': 'Ashtabula',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.86505',
#   'longitude': '-80.78981'},
#  {'area-code': '440',
#   'city': 'Eastlake',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.65394',
#   'longitude': '-81.45039'},
#  {'area-code': '440',
#   'city': 'Elyria',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.36838',
#   'longitude': '-82.10765'},
#  {'area-code': '440',
#   'city': 'Lorain',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.45282',
#   'longitude': '-82.18237'},
#  {'area-code': '440',
#   'city': 'Mentor',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.66616',
#   'longitude': '-81.33955'},
#  {'area-code': '440',
#   'city': 'North Olmsted',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.4156',
#   'longitude': '-81.92347'},
#  {'area-code': '440',
#   'city': 'North Ridgeville',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.38949',
#   'longitude': '-82.01903'},
#  {'area-code': '440',
#   'city': 'North Royalton',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.31366',
#   'longitude': '-81.72457'},
#  {'area-code': '440',
#   'city': 'Parma',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.40477',
#   'longitude': '-81.72291'},
#  {'area-code': '440',
#   'city': 'Parma Heights',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.39005',
#   'longitude': '-81.75958'},
#  {'area-code': '440',
#   'city': 'Rocky River',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.4756',
#   'longitude': '-81.8393'},
#  {'area-code': '440',
#   'city': 'Solon',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.38978',
#   'longitude': '-81.44123'},
#  {'area-code': '440',
#   'city': 'Strongsville',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.3145',
#   'longitude': '-81.83569'},
#  {'area-code': '440',
#   'city': 'Westlake',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.45532',
#   'longitude': '-81.91792'},
#  {'area-code': '440',
#   'city': 'Willoughby',
#   'state': 'Ohio',
#   'country': 'US',
#   'latitude': '41.63977',
#   'longitude': '-81.4065'},
#  {'area-code': '442',
#   'city': 'La Quinta',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.66336',
#   'longitude': '-116.31001'},
#  {'area-code': '442',
#   'city': 'Oceanside',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.19587',
#   'longitude': '-117.37948'},
#  {'area-code': '442',
#   'city': 'Palm Desert',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.72255',
#   'longitude': '-116.37697'},
#  {'area-code': '442',
#   'city': 'Palm Springs',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.8303',
#   'longitude': '-116.54529'},
#  {'area-code': '442',
#   'city': 'Ridgecrest',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '35.62246',
#   'longitude': '-117.6709'},
#  {'area-code': '442',
#   'city': 'San Marcos',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.14337',
#   'longitude': '-117.16614'},
#  {'area-code': '442',
#   'city': 'Victorville',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '34.53611',
#   'longitude': '-117.29116'},
#  {'area-code': '442',
#   'city': 'Vista',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.20004',
#   'longitude': '-117.24254'},
#  {'area-code': '442',
#   'city': 'Apple Valley',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '34.50083',
#   'longitude': '-117.18588'},
#  {'area-code': '442',
#   'city': 'Barstow',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '34.89859',
#   'longitude': '-117.02282'},
#  {'area-code': '442',
#   'city': 'Brawley',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '32.97866',
#   'longitude': '-115.53027'},
#  {'area-code': '442',
#   'city': 'Calexico',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '32.67895',
#   'longitude': '-115.49888'},
#  {'area-code': '442',
#   'city': 'Carlsbad',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.15809',
#   'longitude': '-117.35059'},
#  {'area-code': '442',
#   'city': 'Cathedral City',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.77974',
#   'longitude': '-116.46529'},
#  {'area-code': '442',
#   'city': 'Coachella',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.6803',
#   'longitude': '-116.17389'},
#  {'area-code': '442',
#   'city': 'El Centro',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '32.792',
#   'longitude': '-115.56305'},
#  {'area-code': '442',
#   'city': 'Encinitas',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.03699',
#   'longitude': '-117.29198'},
#  {'area-code': '442',
#   'city': 'Escondido',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.11921',
#   'longitude': '-117.08642'},
#  {'area-code': '442',
#   'city': 'Fallbrook',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.37642',
#   'longitude': '-117.25115'},
#  {'area-code': '442',
#   'city': 'Hesperia',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '34.42639',
#   'longitude': '-117.30088'},
#  {'area-code': '442',
#   'city': 'Indio',
#   'state': 'California',
#   'country': 'US',
#   'latitude': '33.7207',
#   'longitude': '-116.21677'},
#  {'area-code': '443',
#   'city': 'Annapolis',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.97845',
#   'longitude': '-76.49218'},
#  {'area-code': '443',
#   'city': 'Arbutus',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.25455',
#   'longitude': '-76.69997'},
#  {'area-code': '443',
#   'city': 'Arnold',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.03206',
#   'longitude': '-76.50274'},
#  {'area-code': '443',
#   'city': 'Baltimore',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.29038',
#   'longitude': '-76.61219'},
#  {'area-code': '443',
#   'city': 'Bel Air North',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.55429',
#   'longitude': '-76.37309'},
#  {'area-code': '443',
#   'city': 'Bel Air South',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.50506',
#   'longitude': '-76.31977'},
#  {'area-code': '443',
#   'city': 'Carney',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.39427',
#   'longitude': '-76.52358'},
#  {'area-code': '443',
#   'city': 'Catonsville',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.27205',
#   'longitude': '-76.73192'},
#  {'area-code': '443',
#   'city': 'Columbia',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.24038',
#   'longitude': '-76.83942'},
#  {'area-code': '443',
#   'city': 'Crofton',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.00178',
#   'longitude': '-76.68747'},
#  {'area-code': '443',
#   'city': 'Dundalk',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.25066',
#   'longitude': '-76.52052'},
#  {'area-code': '443',
#   'city': 'Edgewood',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.41872',
#   'longitude': '-76.2944'},
#  {'area-code': '443',
#   'city': 'Eldersburg',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.40371',
#   'longitude': '-76.95026'},
#  {'area-code': '443',
#   'city': 'West Elkridge',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.20705',
#   'longitude': '-76.72692'},
#  {'area-code': '443',
#   'city': 'Ellicott City',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.26733',
#   'longitude': '-76.79831'},
#  {'area-code': '443',
#   'city': 'Essex',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.30927',
#   'longitude': '-76.47496'},
#  {'area-code': '443',
#   'city': 'Glen Burnie',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.16261',
#   'longitude': '-76.62469'},
#  {'area-code': '443',
#   'city': 'Lochearn',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.34066',
#   'longitude': '-76.72219'},
#  {'area-code': '443',
#   'city': 'Middle River',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.33427',
#   'longitude': '-76.43941'},
#  {'area-code': '443',
#   'city': 'Milford Mill',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.34788',
#   'longitude': '-76.76997'},
#  {'area-code': '443',
#   'city': 'Odenton',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.084',
#   'longitude': '-76.70025'},
#  {'area-code': '443',
#   'city': 'Parkville',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.37733',
#   'longitude': '-76.53969'},
#  {'area-code': '443',
#   'city': 'Perry Hall',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.41261',
#   'longitude': '-76.46357'},
#  {'area-code': '443',
#   'city': 'Pikesville',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.37427',
#   'longitude': '-76.72247'},
#  {'area-code': '443',
#   'city': 'Randallstown',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.36733',
#   'longitude': '-76.79525'},
#  {'area-code': '443',
#   'city': 'Reisterstown',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.46976',
#   'longitude': '-76.8319'},
#  {'area-code': '443',
#   'city': 'Salisbury',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '38.36067',
#   'longitude': '-75.59937'},
#  {'area-code': '443',
#   'city': 'Severn',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.13705',
#   'longitude': '-76.6983'},
#  {'area-code': '443',
#   'city': 'Severna Park',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.07039',
#   'longitude': '-76.54524'},
#  {'area-code': '443',
#   'city': 'South Gate',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.129',
#   'longitude': '-76.6258'},
#  {'area-code': '443',
#   'city': 'Towson',
#   'state': 'Maryland',
#   'country': 'US',
#   'latitude': '39.4015',
#   'longitude': '-76.60191'},
#  {'area-code': '458',
#   'city': 'Albany',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '44.63651',
#   'longitude': '-123.10593'},
#  {'area-code': '458',
#   'city': 'North Bend',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '43.4065',
#   'longitude': '-124.22428'},
#  {'area-code': '458',
#   'city': 'Corvallis',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '44.56457',
#   'longitude': '-123.26204'},
#  {'area-code': '458',
#   'city': 'Gresham',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '45.49818',
#   'longitude': '-122.43148'},
#  {'area-code': '458',
#   'city': 'Grants Pass',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '42.43933',
#   'longitude': '-123.33067'},
#  {'area-code': '458',
#   'city': 'Medford',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '42.32652',
#   'longitude': '-122.87559'},
#  {'area-code': '458',
#   'city': 'Roseburg North',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '43.26452',
#   'longitude': '-123.30331'},
#  {'area-code': '458',
#   'city': 'Springfield',
#   'state': 'Oregon',
#   'country': 'US',
#   'latitude': '44.04624',
#   'longitude': '-123.02203'},
#  {'area-code': '469',
#   'city': 'Allen',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.10317',
#   'longitude': '-96.67055'},
#  {'area-code': '469',
#   'city': 'Carrollton',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.95373',
#   'longitude': '-96.89028'},
#  {'area-code': '469',
#   'city': 'Cedar Hill',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.58847',
#   'longitude': '-96.95612'},
#  {'area-code': '469',
#   'city': 'Coppell',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.95457',
#   'longitude': '-97.01501'},
#  {'area-code': '469',
#   'city': 'Dallas',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.78306',
#   'longitude': '-96.80667'},
#  {'area-code': '469',
#   'city': 'DeSoto',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.58986',
#   'longitude': '-96.85695'},
#  {'area-code': '469',
#   'city': 'Duncanville',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.6518',
#   'longitude': '-96.90834'},
#  {'area-code': '469',
#   'city': 'Farmers Branch',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.92651',
#   'longitude': '-96.89612'},
#  {'area-code': '469',
#   'city': 'Flower Mound',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.01457',
#   'longitude': '-97.09696'},
#  {'area-code': '469',
#   'city': 'Frisco',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.15067',
#   'longitude': '-96.82361'},
#  {'area-code': '469',
#   'city': 'Garland',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.91262',
#   'longitude': '-96.63888'},
#  {'area-code': '469',
#   'city': 'Grand Prairie',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.74596',
#   'longitude': '-96.99778'},
#  {'area-code': '469',
#   'city': 'Irving',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.81402',
#   'longitude': '-96.94889'},
#  {'area-code': '469',
#   'city': 'Lancaster',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.59208',
#   'longitude': '-96.75611'},
#  {'area-code': '469',
#   'city': 'Lewisville',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.04623',
#   'longitude': '-96.99417'},
#  {'area-code': '469',
#   'city': 'McKinney',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.19762',
#   'longitude': '-96.61527'},
#  {'area-code': '469',
#   'city': 'Mesquite',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.7668',
#   'longitude': '-96.59916'},
#  {'area-code': '469',
#   'city': 'Plano',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.01984',
#   'longitude': '-96.69889'},
#  {'area-code': '469',
#   'city': 'Richardson',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.94818',
#   'longitude': '-96.72972'},
#  {'area-code': '469',
#   'city': 'Rowlett',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.9029',
#   'longitude': '-96.56388'},
#  {'area-code': '469',
#   'city': 'The Colony',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '33.08901',
#   'longitude': '-96.88639'},
#  {'area-code': '469',
#   'city': 'University Park',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.85013',
#   'longitude': '-96.80028'},
#  {'area-code': '469',
#   'city': 'Waxahachie',
#   'state': 'Texas',
#   'country': 'US',
#   'latitude': '32.38653',
#   'longitude': '-96.84833'},
#  {'area-code': '478',
#   'city': 'Macon',
#   'state': 'Georgia',
#   'country': 'US',
#   'latitude': '32.84069',
#   'longitude': '-83.6324'},
#  {'area-code': '478',
#   'city': 'Warner Robins',
#   'state': 'Georgia',
#   'country': 'US',
#   'latitude': '32.62098',
#   'longitude': '-83.5999'},
#  {'area-code': '479',
#   'city': 'Fayetteville',
#   'state': 'Arkansas',
#   'country': 'US',
#   'latitude': '36.06258',
#   'longitude': '-94.15743'},
#  {'area-code': '479',
#   'city': 'Fort Smith',
#   'state': 'Arkansas',
#   'country': 'US',
#   'latitude': '35.38592',
#   'longitude': '-94.39855'},
#  {'area-code': '479',
#   'city': 'Rogers',
#   'state': 'Arkansas',
#   'country': 'US',
#   'latitude': '36.33202',
#   'longitude': '-94.11854'},
#  {'area-code': '479',
#   'city': 'Russellville',
#   'state': 'Arkansas',
#   'country': 'US',
#   'latitude': '35.27842',
#   'longitude': '-93.13379'},
#  {'area-code': '479',
#   'city': 'Springdale',
#   'state': 'Arkansas',
#   'country': 'US',
#   'latitude': '36.18674',
#   'longitude': '-94.12881'},
#  {'area-code': '480',
#   'city': 'Apache Junction',
#   'state': 'Arizona',
#   'country': 'US',
#   'latitude': '33.41505',
#   'longitude': '-111.54958'},
#  ...]

# %%
# Replace ... with your code
city_state_to_zips = dict()
area_code_to_zips= dict()

for z in zip_code_data:
    city = z['city']
    state_id = z['state_id']
    zip_val = z['zip']
    if (city, state_id) not in city_state_to_zips:
        city_state_to_zips[(city, state_id)]= list()
    city_state_to_zips[(city, state_id)].append(zip_val)
    
for a in area_code_data:
    area_code = a['area-code']
    city_name = a['city']
    state_Name = a['state']
    state_Code = state_name_to_code[state_Name]
    
    if area_code not in area_code_to_zips:
        area_code_to_zips[area_code]= list()
        
    new_tuple = (city_name,state_Code)
    
    if new_tuple in city_state_to_zips:
        area_code_to_zips[area_code].extend(city_state_to_zips[new_tuple])
    
    
print(sorted(area_code_to_zips['530']))
# Out:
# ['95616', '95618', '95695', '95776', '95926', '95928', '95929', '95969', '95973', '95991', '95993', '96001', '96002', '96003', '96150', '96155']

# %% [markdown]
# Run the code block below after running your code to check that it is correct. If you see an output of `Correct` below the block everything is correct. If you see something like `AssertionError`, then you have a mistake.

# %%
# Don't modify this code
assert 'city_state_to_zips' in locals()
assert type(city_state_to_zips) == dict
assert len(city_state_to_zips) == 28113
assert city_state_to_zips[('Davis','CA')] == ['95616', '95618']
assert 'area_code_to_zips' in locals()
assert type(area_code_to_zips) == dict
assert len(area_code_to_zips) == 298
assert sorted(area_code_to_zips['530']) == ['95616', '95618', '95695', '95776', '95926', '95928', '95929', '95969', '95973', '95991', '95993', '96001', '96002', '96003', '96150', '96155']
print('Correct')
# Out:
# Correct

# %% [markdown]
# # Challenge (Saving Files)
# For this excercise you will be learning how to open and save data in a file. You can open (or create a new file) and write the contents to a text file format:
# ```python
# with open(filename_goes_here,'w') as file_variable_name:
#   file_variable_name.write(data_to_store)
# ```
# **NOTE: When opening a file with `'w'` flag, if the file exists the contents will be removed! The `'a'` flag can be used to no truncate file information; however, the data will be written to the end of the file.**
#
# The `filename_goes_here` can be a variable or literal string with the name of the file to be opened. The `'w'` parameter in the open statement says that the file is to be opened for writing. The `with` statement at the beginning says to treat the result the expression before the `as` as the variable name after it (in this case the `file_variable_name`). In practice it is good to open files using the `with` block so that the file is automatically closed when the block of code within the `with` is completed. The `.write()` method writes the contents of `data_to_store` to the file. The `filename_goes_here`, `file_variable_name`, and `data_to_store` variable names could be any valid variable name.
#
# 1. Create a variable called `state_code_out_filename` to hold the filename of the `state_codes_copy.json` (you will be copying the file from first section).
# 1. Open the `state_codes_copy.json` file and write the contents your variable `state_code_raw_data` from  earlier.
# 1. You should be able to see that the `state_codes_copy.json` file is in your list of files now (You may have to refresh).
# 1. Verify your code works with the test block afterward.

# %%
# Replace ... with your code
state_code_out_filename = 'state_codes_copy.json'

with open(state_code_out_filename, 'w') as m:
    m.write(str(state_code_raw_data))

# %% [markdown]
# Run the code block below after running your code to check that it is correct. If you see an output of `Correct` below the block everything is correct. If you see something like `AssertionError`, then you have a mistake.

# %%
# Don't modify this code
import os
import filecmp
import hashlib
assert 'state_code_out_filename' in locals()
assert type(state_code_out_filename) == str
assert state_code_out_filename == 'state_codes_copy.json'
assert 'state_code_raw_data' in locals()
assert type(state_code_raw_data) == str
assert len(state_code_raw_data) == 3773
assert hashlib.md5(state_code_raw_data.encode('utf-8')).hexdigest() == 'aa6718b8b969137de605a87f67b15331'
assert os.path.isfile('state_codes.json')
assert os.path.isfile('state_codes_copy.json')
assert filecmp.cmp('state_codes.json','state_codes_copy.json')
print('Correct')

# %% [markdown]
# # Challenge (Saving CSV Files)
# For this excercise you will be learning how to save data in a CSV formatted file. You will create a file just as you did in the previous section, however, you will be using the `csv.writer` to output in CSV format:
# ```python
# with open(filename_goes_here,'w') as file_variable_name:
#   csv_file_variable_name = csv.writer(file_variable_name,quoting=csv.QUOTE_ALL)
#   csv_file_variable_name.writerow(list_or_tuple_to_write)
# ```
# The `filename_goes_here` can be a variable or literal string with the name of the file to be opened. The `'w'` parameter in the open statement says that the file is to be opened for writing. The `with` statement at the beginning says to treat the result the expression before the `as` as the variable name after it (in this case the `file_variable_name`). In practice it is good to open files using the `with` block so that the file is automatically closed when the block of code within the `with` is completed. The `csv_file_variable_name` is the variable being assigned to the [`csv.writer()`](https://docs.python.org/3/library/csv.html#csv.writer) type. To create the [`csv.writer()`](https://docs.python.org/3/library/csv.html#csv.writer) the function needs the output file variable, but in this code there is an added specification for the `quoting` of the values. The `csv.QUOTE_ALL` will quote all values in the CSV file, this results in slightly larger files, but could potentially avoid ambiguous interpretations of the data when read later. The [`.writerow()`](https://docs.python.org/3/library/csv.html#csv.csvwriter.writerow) method writes the `list_or_tuple_to_write` values to the file. The most common use of the [`csv.writer()`](https://docs.python.org/3/library/csv.html#csv.writer) has a call to [`.writerow()`](https://docs.python.org/3/library/csv.html#csv.csvwriter.writerow) to output the header of the CSV file, and then a loop with a call to [`.writerow()`](https://docs.python.org/3/library/csv.html#csv.csvwriter.writerow) in it to write each data row of the file. The `filename_goes_here`, `file_variable_name`, `csv_file_variable_name`, and `list_or_tuple_to_write` variable names could be any valid variable name.
#
# 1. Create a variable called `zip_to_area_code_filename` to hold the filename of the `zip_to_area_code.csv` (you will be writing out data from the previous combining data section).
# 1. Open the `zip_to_area_code.csv` file and create a [`csv.writer()`](https://docs.python.org/3/library/csv.html#csv.writer) called `zip_to_area_code_csv_writer`.
# 1. Write the header row of `['zip','area code']` out.
# 1. Iterate through the `area_code_data` and in the loop do the following:
#   1. Iterate through each zip code in the area code `area_code_data` and in the loop do the following:
#     1. Write the data row of zip code and area code.
# 1. You should be able to see that the `zip_to_area_code.csv` file is in your list of files now.
# 1. Verify your code works with the test block afterward.

# %%
import csv
# Replace ... with your code
...

# %% [markdown]
# Run the code block below after running your code to check that it is correct. If you see an output of `Correct` below the block everything is correct. If you see something like `AssertionError`, then you have a mistake.

# %%
# Don't modify this code
import os
import filecmp
import hashlib
assert 'zip_to_area_code_filename' in locals()
assert type(zip_to_area_code_filename) == str
assert zip_to_area_code_filename == 'zip_to_area_code.csv'
assert 'zip_to_area_code_csv_writer' in locals()
assert hasattr(zip_to_area_code_csv_writer,'writerow')
assert callable(zip_to_area_code_csv_writer.writerow)
assert os.path.isfile('zip_to_area_code.csv')
with open('zip_to_area_code.csv','r') as in_file:
  zip_area_dict_list = list(csv.DictReader(in_file))
  assert len(zip_area_dict_list) == 8384
  for zip_area_dict in zip_area_dict_list:
    assert len(zip_area_dict) == 2
    assert 'zip' in zip_area_dict
    assert 'area code' in zip_area_dict
    assert zip_area_dict['area code'] in area_code_to_zips
    assert zip_area_dict['zip'] in area_code_to_zips[zip_area_dict['area code']]
print('Correct')
